# %%
from bs4 import BeautifulSoup, SoupStrainer

from urllib.request import urlopen, urlretrieve, quote
from urllib.parse import urljoin

import gzip

import pandas as pd

# %% [markdown]
# ## Loop through states and download data from available sheets:
# #### 1. Outcomes & Factor Rankings - no
# #### 2. Outcomes & Factor SubRankings - no
# #### 3. Ranked Measure Data - yes, raw data
# #### 4. Additional Measure Data - yes, raw data
# #### 5./6. tabs on sources for reference: Ranked Measure Sources & Years and Addtl Measure Sources & Years

# %%
states = {"AL":"Alabama","AK":"Alaska","AZ":"Arizona","AR":"Arkansas","CA":"California","CO":"Colorado","CT":"Connecticut","DE":"Delaware","FL":"Florida","GA":"Georgia","HI":"Hawaii","ID":"Idaho","IL":"Illinois","IN":"Indiana","IA":"Iowa","KS":"Kansas","KY":"Kentucky","LA":"Louisiana","ME":"Maine","MD":"Maryland","MA":"Massachusetts","MI":"Michigan","MN":"Minnesota","MS":"Mississippi","MO":"Missouri","MT":"Montana","NE":"Nebraska","NV":"Nevada","NH":"New Hampshire","NJ":"New Jersey","NM":"New Mexico","NY":"New York","NC":"North Carolina","ND":"North Dakota","OH":"Ohio","OK":"Oklahoma","OR":"Oregon","PA":"Pennsylvania","RI":"Rhode Island","SC":"South Carolina","SD":"South Dakota","TN":"Tennessee","TX":"Texas","UT":"Utah","VT":"Vermont","VA":"Virginia","WA":"Washington","WV":"West Virginia","WI":"Wisconsin","WY":"Wyoming"}

# %%
def file_template(state, version):
    file = f'https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20{state}%20Data%20-%20v{version}.xls'
    return file

# %%
for lkp in states:
    read_state = states[lkp]
    state = read_state.replace(" ", "%20")
    
    # none have a 3rd version
#     try:
#         file = file_template(state, "3")
#         data = pd.read_excel(file, 'Ranked Measure Data')
#         print(file)
#     except:
#         pass
    
    # try to use the latest version first
    # otherwise, if there isn't a version 2, use version 1_0
    try:
        file = file_template(state, "2")
        measure_data = pd.read_excel(file, 'Ranked Measure Data')
    except:
        file = file_template(state, "1_0")
        measure_data = pd.read_excel(file, 'Ranked Measure Data')
        
    print(file)    
    addtl_data = pd.read_excel(file, 'Additional Measure Data')
    measure_data.to_csv(f'N:/Transfer/KSkvoretz/AHRQ/data/01_Demographic/RWJF/Measure_Data_{read_state}.csv')
    addtl_data.to_csv(f'N:/Transfer/KSkvoretz/AHRQ/data/01_Demographic/RWJF/Additional_Data{read_state}.csv')
# Out:
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Alabama%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Alaska%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Arizona%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Arkansas%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20California%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Colorado%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Connecticut%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Delaware%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Florida%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Georgia%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Hawaii%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Idaho%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Illinois%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Indiana%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Iowa%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Kansas%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Kentucky%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Louisiana%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Maine%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Maryland%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Massachusetts%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Michigan%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Minnesota%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Mississippi%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Missouri%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Montana%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Nebraska%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Nevada%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20New%20Hampshire%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20New%20Jersey%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20New%20Mexico%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20New%20York%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20North%20Carolina%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20North%20Dakota%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Ohio%20Data%20-%20v2.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Oklahoma%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Oregon%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Pennsylvania%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Rhode%20Island%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20South%20Carolina%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20South%20Dakota%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Tennessee%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Texas%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Utah%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Vermont%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Virginia%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Washington%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20West%20Virginia%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Wisconsin%20Data%20-%20v1_0.xls
# https://www.countyhealthrankings.org/sites/default/files/state/downloads/2019%20County%20Health%20Rankings%20Wyoming%20Data%20-%20v1_0.xls

# %% [markdown]
# # Other scraping tried

# %%
url = 'https://www.countyhealthrankings.org/app/ohio/2019/downloads'
u = urlopen(url)

try:
    html = gzip.decompress(u.read()).decode('utf-8')
finally:
    u.close()

# %%
print(u)
print(html)
# Out:
# <http.client.HTTPResponse object at 0x000001B948031630>
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="ie6 lt-ie9 lt-ie8 lt-ie7 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 7]>         <html class="ie7 lt-ie9 lt-ie8 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 8]>         <html class="ie8 lt-ie9 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 9]>         <html class="ie9 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if gt IE 9]><!--> <html class="no-js"  lang="en" dir="ltr" prefix="fb: http://www.facebook.com/2008/fbml ng: https://angularjs.org og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"> <!--<![endif]-->
#   <head>
#     <meta http-equiv="X-UA-Compatible" content="chrome=1" />
# <base href="/app/" />
# <meta charset="utf-8" />
#   <!--[if lte IE 8]>
#     <script>
#       document.createElement('ng-include');
#       document.createElement('ng-pluralize');
#       document.createElement('ng-view');
#       document.createElement('ng:include');
#       document.createElement('ng:pluralize');
#       document.createElement('ng:view');
#     </script>
#   <![endif]-->
#   <!--[if lt IE 8]>
#     <script src="js/json2.js"></script>
#   <![endif]-->
#   <meta name="fragment" content="!" /><link rel="shortcut icon" href="https://www.countyhealthrankings.org/sites/all/themes/gesso/favicon.ico" type="image/vnd.microsoft.icon" />
# <meta property="og:site_name" content="County Health Rankings &amp; Roadmaps" />
# <meta property="og:url" content="https://www.countyhealthrankings.org/app" />
# <meta property="og:type" content="article" />
# <meta property="og:title" content="Rankings" />
# <meta property="og:image" content="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/og_logo_map.png" />
# <meta property="og:description" content="The County Health Rankings..." />
# <meta name="generator" content="Drupal 7 (http://drupal.org)" />
# <link rel="canonical" href="https://www.countyhealthrankings.org/app" />
# <link rel="shortlink" href="https://www.countyhealthrankings.org/app" />
#     <title>Rankings | County Health Rankings &amp; Roadmaps</title>
#     <meta name="HandheldFriendly" content="true">
#     <meta name="MobileOptimized" content="width">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <meta http-equiv="cleartype" content="on">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <link href="https://fonts.googleapis.com/css?family=Lato:300,300i,400,400i,700,700i" rel="stylesheet">
#     <link rel="stylesheet" href="https://www.countyhealthrankings.org/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" />
# <link rel="stylesheet" href="https://www.countyhealthrankings.org/sites/default/files/css/css_YHoYfdDHJhBk9fafWDBDsJSjINK488FlQXisjG0rcSQ.css" media="all" />
# <link rel="stylesheet" href="https://www.countyhealthrankings.org/sites/default/files/css/css_HncloJEV201TU1_MXmSB7ZIDGZH0xWVtLayhNIYKF0s.css" media="all" />
# <link rel="stylesheet" href="https://www.countyhealthrankings.org/sites/default/files/css/css_mX0dnWaQH19maUvGx1X4TNoWiae3zKCzVFqtc2v8wqI.css" media="all" />
# <link rel="stylesheet" href="https://www.countyhealthrankings.org/sites/default/files/css/css_aGX4S5Gw2k44t_x0TwnW7sCB3tKEzqVdtGWw8Ux4H0o.css" media="all" />
#     <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_yKlfN2sDjSoaIQBuf095xIT3NbJaeqGCcgyQyxSIU_c.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/all/libraries/modernizr/modernizr-custom.js?pvzj65"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js"></script>
# <script>
# window.jQuery || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/jquery/1.8/jquery.min.js'>\x3C/script>")
# </script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_Ue_83Kva_lTYRWiAZpAX_KdvIaglsnzPVl955H8zZA0.js"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js"></script>
# <script>
# window.jQuery.ui || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/ui/ui/minified/jquery-ui.min.js'>\x3C/script>")
# </script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_fnFMT3X1_bhCDaBABvWwi8Yq5Useb8r_XorbufldYMA.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/all/libraries/mediaelement/build/mediaelement-and-player.min.js?v=2.1.6"></script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_mk-Xe5KDVSFHKVF5qTZ9R3hH-bbwxn47n3Jk66UEVX8.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_ek1MBTY1vP7U5uRFRy0H4a3w5VtVp9IB9gJs4tkJEsI.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_85FQuPhJY-7M8ID4O_j2P0Yje8F2rg9QqB5wfoQ6pNg.js"></script>
# <script>
# window.CKEDITOR_BASEPATH = '/sites/all/libraries/ckeditor/'
# </script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_KYDbIQSYZ5htJJEkNT3Pt7h5jt7q5MWTORGvQEf1WaM.js"></script>
# <script>
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"gesso","theme_token":"VfYT13i54A9CqIFcEmpLbSgQlJj9QEKyX5lTvRnTTZY","css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelementplayer.min.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.menu.css":1,"misc\/ui\/jquery.ui.autocomplete.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/fitvids\/fitvids.css":1,"sites\/all\/modules\/contrib\/footnotes\/footnotes.css":1,"sites\/all\/modules\/contrib\/menu_attach_block\/menu_attach_block.css":1,"modules\/node\/node.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/libraries\/angular-ui-select\/dist\/select.min.css":1,"sites\/all\/libraries\/select2\/select2.css":1,"sites\/all\/libraries\/bootstrap\/dist\/css\/bootstrap.css":1,"sites\/all\/libraries\/angular-motion\/dist\/angular-motion.css":1,"sites\/all\/modules\/custom\/chr_data\/css\/controls.css":1,"sites\/all\/modules\/custom\/chr_data\/css\/tablesorter.css":1,"sites\/all\/libraries\/fontawesome\/css\/font-awesome.css":1,"sites\/all\/themes\/gesso\/css\/styles.css":1},"js":{"sites\/all\/modules\/custom\/chr_data\/dist\/app.js":1,"sites\/all\/modules\/contrib\/addthis\/addthis.js":1,"public:\/\/google_tag\/google_tag.script.js":1,"sites\/all\/libraries\/modernizr\/modernizr-custom.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jquery\/1.8.3\/jquery.min.js":1,"0":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/libraries\/fitvids\/jquery.fitvids.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jqueryui\/1.10.2\/jquery-ui.min.js":1,"1":1,"sites\/all\/modules\/contrib\/beautytips\/js\/jquery.bt.min.js":1,"sites\/all\/modules\/contrib\/beautytips\/js\/beautytips.min.js":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelement-and-player.min.js":1,"https:\/\/polyfill.io\/v3\/polyfill.min.js?features=URL,fetch,Promise":1,"sites\/all\/modules\/custom\/chr_ww_source\/chr_ww_source.js":1,"sites\/all\/modules\/contrib\/fitvids\/fitvids.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/modules\/contrib\/mediaelement\/mediaelement.js":1,"sites\/all\/libraries\/json3\/lib\/json3.js":1,"sites\/all\/libraries\/angular\/angular.js":1,"sites\/all\/libraries\/angular-resource\/angular-resource.js":1,"sites\/all\/libraries\/angular-cookies\/angular-cookies.js":1,"sites\/all\/libraries\/angular-cookies-1-5-9\/angular-cookies.js":1,"sites\/all\/libraries\/angular-sanitize\/angular-sanitize.js":1,"sites\/all\/libraries\/angular-animate\/angular-animate.js":1,"sites\/all\/libraries\/angular-class\/angular-class.js":1,"sites\/all\/libraries\/angular-translate\/dist\/angular-translate.js":1,"sites\/all\/libraries\/angular-translate\/dist\/angular-translate-loader-static-files\/angular-translate-loader-static-files.js":1,"sites\/all\/libraries\/angular-ui-select\/dist\/select.min.js":1,"sites\/all\/libraries\/html5shiv\/dist\/html5shiv.js":1,"sites\/all\/libraries\/es5-shim\/es5-shim.min.js":1,"sites\/all\/libraries\/angular-ui-utils\/index.js":1,"sites\/all\/libraries\/angular-ui-scroll\/dist\/ui-scroll.js":1,"sites\/all\/libraries\/angular-ui-scrollpoint\/dist\/scrollpoint.js":1,"sites\/all\/li ...
# </script>
#   </head>
#   <body class="not-front not-logged-in page-app path-app section-app page-panels">
#     <div class="skiplinks">
#       <a href="#main" class="skiplinks__link visually-hidden focusable">Skip to main content</a>
#     </div>
#         <noscript aria-hidden="true"><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-M9JNG4Z" height="0" width="0" style="display:none;visibility:hidden" title="Google Tag Manager">Google Tag Manager</iframe></noscript>      <div class="site-container">
#
#
#   <div class="print-header">
#     <div class="l-constrain">
#       <img src="/sites/all/themes/gesso/images/printlogo_full.png" alt="County Health Rankings & Roadmaps, A Healthier Nation, County by County">
#     </div>
#   </div>
#
#   <header class="header" role="banner">
#     <div class="region-header">
#       <div class="l-constrain">
#         <div class="region-header__first">
#             <a class="site-name" href="/" rel="home">
#   <h1 class="site-name__text">County Health Rankings &amp; Roadmaps</h1>
# </a>
#         </div>
#         <div class="region-header__second">
#             <div id="block-menu-menu-utility-menu" class="block  block-menu-menu-utility-menu block--menu block--menu-menu-utility-menu">    <h2 class="element-invisible block__title">Utility Menu</h2>
#   <ul class="nav"><li class="nav__item nav__item--first"><a href="/about-us" title="" class="nav__link">About Us</a></li>
# <li class="nav__item nav__item--last"><a href="/news-events" title="" class="nav__link">News &amp; Events</a></li>
# </ul>  </div>          <a href="http://www.rwjf.org/" class="header-rwjf-logo">A Robert Wood Johnson Foundation program</a>
#         </div>
#       </div>
#     </div>
#   </header>
#
#         <div class="region-navigation">    <div class="l-constrain">
#       <div class="region-navigation__inner">
#         <div id="block-system-main-menu" class="block  block-system-main-menu block--system block--system-main-menu">    <h2 class="element-invisible block__title">Main menu</h2>
#   <ul class="nav"><li class="nav__item nav__item--first is-expanded has-children has-subnav"><a href="/explore-health-rankings" class="nav__link">Explore Health Rankings</a><ul class="nav nav--subnav"><li class="nav__item nav__item--first is-collapsed has-children"><a href="/explore-health-rankings/use-data" class="nav__link">Use the Data</a></li>
# <li class="nav__item is-collapsed has-children"><a href="/explore-health-rankings/measures-data-sources" class="nav__link">Measures &amp; Data Sources</a></li>
# <li class="nav__item is-collapsed has-children"><a href="/explore-health-rankings/our-methods" class="nav__link">Our Methods</a></li>
# <li class="nav__item is-collapsed has-children"><a href="/explore-health-rankings/measuring-progress" class="nav__link">Measuring Progress</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a href="/explore-health-rankings/rankings-data-documentation" class="nav__link">Rankings Data &amp; Documentation</a></li>
# </ul></li>
# <li class="nav__item is-expanded has-children has-subnav"><a href="/take-action-to-improve-health" class="nav__link">Take Action to Improve Health</a><ul class="nav nav--subnav"><li class="nav__item nav__item--first is-collapsed has-children"><a href="/take-action-to-improve-health/what-works-for-health" class="nav__link">What Works for Health</a></li>
# <li class="nav__item is-collapsed has-children"><a href="/take-action-to-improve-health/action-center" class="nav__link">Action Center</a></li>
# <li class="nav__item is-collapsed has-children"><a href="/take-action-to-improve-health/partner-center" class="nav__link">Partner Center</a></li>
# <li class="nav__item"><a href="/take-action-improve-health/community-coaching" class="nav__link">Community Learning &amp; Guidance</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a href="/take-action-to-improve-health/learning-guides" class="nav__link">Action Learning Guides</a></li>
# </ul></li>
# <li class="nav__item is-expanded has-children has-subnav"><a href="/learn-from-others" class="nav__link">Learn From Others</a><ul class="nav nav--subnav"><li class="nav__item nav__item--first is-collapsed has-children"><a href="/webinars" title="" class="nav__link">Webinars</a></li>
# <li class="nav__item is-collapsed has-children"><a href="/learn-from-others/rwjf-culture-of-health-prize" class="nav__link">RWJF Culture of Health Prize</a></li>
# <li class="nav__item"><a href="/learn-others/working-with-others" class="nav__link">Working With Others</a></li>
# <li class="nav__item"><a href="/learn-others/research-articles" class="nav__link">Research Articles</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a href="/learn-from-others/stories" class="nav__link">Stories</a></li>
# </ul></li>
# <li class="nav__item"><a href="/what-is-health" class="nav__link">What Is Health?</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a href="/reports" class="nav__link">Reports</a></li>
# </ul>  </div>        <button class="region-navigation__search-button">Search</button>
#       </div>
#     </div>
#   </div>
#         <div class="region-search">    <div class="l-constrain">
#       <div id="block-views-exp-search-results-search-pane" class="block  block-views-exp-search-results-search-pane block--views block--views--exp-search-results-search-pane">      <form action="/search" method="get" id="views-exposed-form-search-results-search-pane" accept-charset="UTF-8">      <div id="edit-search-api-views-fulltext-wrapper" class="views-widget views-widget--filter-search_api_views_fulltext">
#                   <input placeholder="Search by county, state, or topic" type="text" id="edit-search-api-views-fulltext" name="search_api_views_fulltext" value="" size="30" maxlength="128" class="form-text form-autocomplete live-results-search-textfield" /><input type="hidden" id="edit-search-api-views-fulltext-autocomplete" value="https://www.countyhealthrankings.org/search_api_live_results/search_api_views_search_results" disabled="disabled" class="live-result-autocomplete" />          </div>
#           <div class="views-widget views-widget--submit">
#     <input type="submit" id="edit-submit-search-results" name="" value="Search" class="button button--submit">  </div>
#   </form>  </div>    </div>
#   </div>
#
#
#         <div class="region-breadcrumb-region">    <div class="l-constrain">
#       <div id="block-blockify-blockify-breadcrumb" class="block  block-blockify-blockify-breadcrumb block--blockify block--blockify-blockify-breadcrumb">      <nav class="breadcrumb" role="navigation"><h2 class="breadcrumb__title">You are here</h2><ol class="breadcrumb__list"><li class="breadcrumb__item"><a href="/">Home</a></li></ol></nav>  </div><div id="block-addthis-addthis-block" class="block  block-addthis-addthis-block block--addthis block--addthis-addthis-block">      <div class="addthis_toolbox addthis_default_style addthis_16x16_style "><a class="addthis_button_print"></a>
# <a class="addthis_button_email"></a>
# <a class="addthis_button_facebook"></a>
# <a class="addthis_button_twitter"></a>
# </div>
#   </div>    </div>
#   </div>
#       <main id="main" class="main" role="main" tabindex="-1">
#         <div class="l-single-column">
#   <div class="l-constrain">
#     <div class="l-single-column__main">        <div class="pane pane--app">
#
#
#
#     <div class="pane__content">
#       <div class="ng-app:app" id="ng-app" ng-app="app"><!--[if IE 8]>
#   <div id="ie8-warning" class="chr-messages warning">
#     <p><strong>Internet Explorer 8 is no longer supported.</strong> You may proceed with using your current browser, but functionality may be limited.</p>
#     <p>For a better experience, try a newer version of <a href="http://windows.microsoft.com/ie" target="_blank">Internet Explorer</a>, <a href="http://www.google.com/chrome/" target="_blank">Chrome</a>, or <a href="http://www.firefox.com/" target="_blank">Firefox</a>.</p>
#   </div>
# <![endif]-->
# <!--[if lt IE 8]>
#   <script type="text/javascript"
#    src="http://ajax.googleapis.com/ajax/libs/chrome-frame/1/CFInstall.min.js"></script>
#   <style>
#    .chromeFrameInstallDefaultStyle {
#      width: 850px; /* default is 800px */
#      border: 5px solid blue;
#    }
#   </style>
#   <div id="chrome-prompt">
#     You are using an old version of Internet Explorer that is incompatible with this website.<br />
#     For faster browsing and a working back button...<br />
#     <button type="button" onclick="installChrome()">Install Google's Chrome Frame plugin</button>
#   </div>
#   <script>
#    // The conditional ensures that this code will only execute in IE,
#    // Therefore we can use the IE-specific attachEvent without worry
#    var installChrome = function() {
#      CFInstall.check({
#        mode: "inline", // the default
#        node: "chrome-prompt",
#        url: "http://www.google.com/chromeframe/eula.html",
#        destination: window.location.href
#      });
#    };
#  </script>
# <![endif]-->
# <div id="app-main" ng-controller="MainController" ng-class="{'is-dc': isDC}" class="section-{{section}} subsection-{{subsection}} category-{{category}}">
#   <div social-widgets="social-widgets"></div>
#   <div class="app-header breadcrumb">
#     <h1 class="state-header"><a ng-cloak ui-sref="overview" class="back-to-state ng-cloak">{{state.name}}</a></h1>
#     <div class="statePathDateSelect">
#       <ui-select class="app-year-select" theme="select2" ng-model="year" skip-focusser="true" on-select="selectYear(year)">
#         <ui-select-match placeholder="Select a year">
#           <span ng-bind="$select.selected"></span>
#         </ui-select-match>
#         <ui-select-choices repeat="year in years | validYears:$stateParams.measure:measures | filter: $select.search | orderBy:year:true">
#           <span ng-bind-html="year | highlight: $select.search"></span>
#         </ui-select-choices>
#         <ui-select-no-choice>
#           <span ng-cloak>No Matches Found</span>
#         </ui-select-no-choice>
#       </ui-select>
#       <ui-select class="app-state-select" theme="select2" ng-model="statePath" skip-focusser="true" on-select="selectState(statePath)" resetselectlist>
#         <ui-select-match placeholder="{{'SELECT_STATE' | translate}}">
#           <span ng-bind="$select.selected.name"></span>
#         </ui-select-match>
#         <ui-select-choices repeat="state in states | toArray | orderBy:'name' | filter: {'name':$select.search}">
#           <span ng-bind-html="state | highlight: $select.search"></span>
#         </ui-select-choices>
#         <ui-select-no-choice>
#           <span ng-cloak>No Matches Found</span>
#         </ui-select-no-choice>
#       </ui-select>
#     </div>
#   </div>
#   <div id="app-wrapper">
#     <div ui-view="header" class="app-header nav clearfix"></div>
#     <div id="app-body" ui-view="body"></div>
#     <div id="app-footer" ui-view="footer"></div>
#   </div>
# </div>
# <script type="text/ng-template" id="partials/app--embeddable.html"><!--[if IE 8]>
# <div id="ie8-warning" class="chr-messages warning">
#   <p><strong>Internet Explorer 8 is no longer supported.</strong> You may proceed with using your current browser, but functionality may be limited.</p>
#   <p>For a better experience, try a newer version of <a href="http://windows.microsoft.com/ie" target="_blank">Internet Explorer</a>, <a href="http://www.google.com/chrome/" target="_blank">Chrome</a>, or <a href="http://www.firefox.com/" target="_blank">Firefox</a>.</p>
# </div>
# <![endif]-->
# <!--[if lt IE 8]>
# <script type="text/javascript"
#         src="http://ajax.googleapis.com/ajax/libs/chrome-frame/1/CFInstall.min.js"></script>
# <style>
#   .chromeFrameInstallDefaultStyle {
#     width: 850px; /* default is 800px */
#     border: 5px solid blue;
#   }
# </style>
# <div id="chrome-prompt">
#   You are using an old version of Internet Explorer that is incompatible with this website.<br />
#   For faster browsing and a working back button...<br />
#   <button type="button" onclick="installChrome()">Install Google's Chrome Frame plugin</button>
# </div>
# <script>
#   // The conditional ensures that this code will only execute in IE,
#   // Therefore we can use the IE-specific attachEvent without worry
#   var installChrome = function() {
#     CFInstall.check({
#       mode: "inline", // the default
#       node: "chrome-prompt",
#       url: "http://www.google.com/chromeframe/eula.html",
#       destination: window.location.href
#     });
#   };
# </script>
# <![endif]-->
# <div id="app-main" ng-controller="MainController" ng-class="{'is-dc': isDC}" class="section-{{section}} subsection-{{subsection}} category-{{category}}">
#   <div id="app-wrapper">
#     <div id="app-body" ui-view="body"></div>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/404.html"><h1>page not found</h1>
#
# <h3>{{text}}</h3>
# </script><script type="text/ng-template" id="partials/map.html"><div class="map-wrapper">
#   <div class="map">
#   </div>
#   <div class="legend-wrapper legend-{{legendType}} category-{{category}}" ng-switch="legendType">
#     <div ng-switch-when="gradient" class="legend legend-gradient">
#       <span class="caption legend-best">Best</span>
#       <span class="legend-key">&nbsp;</span>
#       <span class="caption legend-worst">Worst</span>
#       <div class="caption nr">Missing</div>
#       <div ng-if="notApplicableExists" class="not-applicable">
#         <div class="caption">No Data</div>
#         <span class="caption"></span>
#       </div>
#     </div>
#     <div ng-switch-default class="legend legend-quartile map-ranges">
#       <div class="caption">Rank</div>
#       <span ng-repeat="(quartile,range) in ranges" class="quartile {{quartile}}">{{range}}</span>
#       <div class="caption nr">Not Ranked (NR)</div>
#       <div ng-if="notApplicableExists" class="not-applicable">
#           <div class="caption">No Data</div>
#           <span class="caption"></span>
#       </div>
#     </div>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/rankings.html"><div id="main" class="app-section has-sidebar">
#     <div id="sidebar" ui-view="sidebar">
#   </div>
#   <div id="main-inner-wrapper" class="app-section" ui-view>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/rankings-sidebar.html"><div class="back-to-map-wrapper" ng-if="!mobile && ($state.includes('rankings.county')) && !isDC">
#   <a class="back-to-map noPrint" ui-sref="rankings.state({category: $stateParams.category, component: $stateParams.component})" translate="BACK_TO_MAP">Back to map</a>
# </div>
# <div measures-navigation ng-if="!mobile || !$state.includes('rankings.county')"></div>
# <div county-rankings-table ng-if="(!mobile || !$state.includes('rankings.county')) && !isDC"></div>
# <div ng-if="!mobile" class="translation-links" ng-show="$state.is('rankings.county.snapshot')">
#   <button class="button" ng-click="toggleLanguage()" translate="CURRENT_LANGUAGE"></button>
# </div>
# </script><script type="text/ng-template" id="partials/rankings-state.html"><div ng-if="!mobile" class="tab-context">
#   <h2 class="ranking-title title">{{rankingsTitle}}</h2>
#   <p class="ranking-description description" ng-show="rankingsDescription">{{rankingsDescription}}</p>
# </div>
# <div ng-if="!mobile" chr-map="chr-map" app-map-type="{{mapType}}" app-category="{{$stateParams.category}}" app-year="{{year}}" app-state="state" app-id="{{mapId}}" tooltip="tooltip(state, county)"></div>
# <div ng-if="county_boundary_note" class="county-boundary-note">
#     <p ng-bind-html="county_boundary_note"></p>
# </div>
# </script><script type="text/ng-template" id="partials/rankings-county.html"><div ng-if="!snapshot-printing" id="county-header" class="clearfix tab-context">
#   <div ng-if="dataLoaded" class="app-header">
#     <h2 class="county-name title">
#       {{countyName}}
#     </h2>
#     <div ng-if="$stateParams.year == settings.default_year" class="areas-to-explore" tooltip="{{exploreTooltip}}" tooltip-placement="top">
#       <input id="highlight-explore" ng-model="highlight" type="checkbox" ng-change="toggleExplore(highlight)">
#       <label for="highlight-explore" translate="EXPLORE_AREAS">Show areas to explore</label>
#       <input id="highlight-strength" ng-model="highlightStrength" type="checkbox" ng-change="toggleStrength(highlightStrength)">
#       <label for="highlight-strength" translate="EXPLORE_AREAS_STRENGTH">>Show areas of strength</label>
#     </div>
#   </div>
# </div>
# <div ng-if="dataLoaded" ng-class="{ 'snapshot-printing': snapshot_printing, 'demographics' : true}">
#   <table class="demographics-header-table">
#     <thead>
#       <tr>
#         <th>
#           <h3 ng-click="showDemographics = !showDemographics">{{ "DEMOGRAPHIC_LABEL" | translate }} <span ng-hide="snapshot_printing" class="show-hide">{{ showDemographics ? '&#8722;' : '+'}}</span></h3>
#         </th>
#       </tr>
#     </thead>
#   </table>
#   <div ng-show="(showDemographics || snapshot_printing)" class="demographics-table-wrapper"">
#     <table>
#       <thead>
#         <tr>
#           <th class="title-th-name">&nbsp;</th>
#           <th ng-show="!snapshot_printing">&nbsp;</th>
#           <th translate="COUNTY_LABEL">County</th>
#           <th translate="STATE_LABEL">State</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr ng-repeat="row in county.demographics | orderBy: ['-measure_type', 'display_index']" ng-if="!row.view || row.view === 0">
#           <td>
#             <a ng-show="!snapshot_printing" ui-sref="measures.state.tab({ category: 'factors', measure: row.id, tab: 'data' })" translate={{"DEMOGRAPHIC_"+row.id+"_NAME"}}>{{ row.name }}</a>
#             <span ng-show="snapshot_printing" translate={{"DEMOGRAPHIC_"+row.id+"_NAME"}}>{{ row.name }}</span>
#             <span class="symbol measure-footnote" ng-if="snapshot_printing && row.hasFootnote == 1">{{ row.footnoteSymbol }}</span>
#           </td>
#           <td ng-show="!snapshot_printing" class="info">
#             <span ng-if="row.hasFootnote == 1" class="fa fa-info-circle"
#             data-bs-popover="footnotePopover"
#             data-placement="bottom"
#             data-trigger="click"
#             data-container="body"
#             data-content="{{'FOOTNOTE_'+row.footnote_id | translate}}"
#             data-event-type="snapshot"
#             data-event-key-1="County Demographics"
#             data-event-key-2="{{$stateParams.year}}"
#             data-html="true"><span>(Click for info)</span>
#             </span>
#             <span ng-if="row.hasFootnote != 1">&nbsp;</span>
#           </td>
#           <td ng-bind-html="row.county_value"></td>
#           <td ng-bind-html="row.state_value"></td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
# </div>
# <div ng-if="dataLoaded" class="content" ui-view>
# </div>
# </script><script type="text/ng-template" id="partials/rankings-county-additional.html"><div class="additional">
#   <div ng-if="county.additional" ng-bind-html="county.additional">
#     <p ng-if="!dataLoaded" class="loading">Loading additional measures data.</p>
#   </div>
#   <div ng-if="county.additional == ''" class="empty">
#     <p>There are no additional measures for this year to display.</p>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/rankings-county-snapshot.html"><div class="snapshot state-{{current.state_fips}}">
#     <table class="sticky-enabled snapshot-data">
#         <thead>
#         <tr>
#             <th class="title-th-name">&nbsp;</th>
#             <th ng-if="!snapshot_printing" class="noPrint">&nbsp;</th>
#             <!-- County name -->
#             <th class="place-name"><span translate="COUNTY_LABEL_PREFIX"></span><span ng-bind-html="county.countyNameHeading"></span><br /><span ng-show="!isTranslated()" translate="COUNTY_LABEL"></span></th>
#             <th ng-if="isDefaultYear" class="trend mobile-drop info">
#                 <span translate="TREND" class="colname">Trend</span>
#                 <span ng-if="!snapshot_printing" class="fa fa-info-circle"
#                       data-bs-popover="trendHeaderTooltip"
#                       data-placement="bottom"
#                       data-trigger="click"
#                       data-event-type="snapshot"
#                       data-event-key-1="Trend"
#                       data-event-key-2="{{current.year}}"
#                       data-content-template="partials/trend-info-tooltip.html"><span>(Click for info)</span></span>
#             </th>
#             <th class="error-margin mobile-drop" translate-attr="{title: 'ERROR_TITLE'}" translate="ERROR_MARGIN">Error<br />Margin</th>
#             <th class="target-value mobile-drop info">
#               <span translate="US_PERFORMERS_LABEL">Top U.S.<br />Performers</span>
#               <span ng-if="snapshot_printing" class="symbol">{{county.footnotes['1'].symbol}}</span>
#               <span ng-if="!snapshot_printing" class="fa fa-info-circle noPrint"
#                 data-bs-popover="topPerformersHeaderTooltip"
#                 data-placement="bottom"
#                 data-trigger="click"
#                 data-event-type="snapshot"
#                 data-event-key-1="Top Performers"
#                 data-event-key-2="{{current.year}}"
#                 data-content-template="partials/top-performers-tooltip.html"><span>(Click for info)</span></span></th>
#             <!-- Statename. -->
#             <th ng-if="current.state_fips != '11'" class="value" title="Overall value for the entire state">{{county.stateName}}</th>
#             <th ng-if="current.state_fips != '11'" class="rank info"><span translate="RANK_OF">Rank<br />(of </span><span>{{county.countiesRankedInState}})</span>
#                 <span ng-if="!snapshot_printing" class="fa fa-info-circle"
#                       data-bs-popover="rankHeaderTooltip"
#                       data-placement="bottom"
#                       data-trigger="click"
#                       data-event-type="snapshot"
#                       data-event-key-1="Rank"
#                       data-event-key-2="{{current.year}}"
#                       data-content-template="partials/rank-info-tooltip.html"><span>(Click for info)</span></span>
#             </th>
#         </tr>
#         </thead>
#
#         <!-- Category Header -->
#         <tbody ng-repeat-start="(categoryId, category) in county.categoryArray" id="category-id-{{categoryId}}" class="category">
#         <tr class="category category-id-{{categoryId}}">
#             <td colspan="{{getHeaderColSpan({base: 6, dc: -1, trend: 1})}}" translate={{"CATEGORY_"+category.id}} class="name category-name">{{category.name}}</td>
#             <td ng-if="current.state_fips != '11'" class="rank category-rank">{{category.rank}}</td>
#         </tr>
#         </tbody>
#
#         <!-- Factor Header -->
#         <tbody ng-repeat-start="component in category.components" id="component-id-{{component.id}}" class="component expanded">
#         <tr class="component">
#             <td colspan="{{getHeaderColSpan({base: 6, dc: -1, trend: 1})}}" ng-click="component.hideRanked = !component.hideRanked" translate={{"FACTOR_"+component.id}} class="name component-name">{{component.componentName}}</td>
#             <td ng-if="current.state_fips != '11'" class="rank component-rank">{{component.rank}}</td>
#         </tr>
#         </tbody>
#
#         <!-- Factor Body -->
#         <tbody ng-hide="component.hideRanked" class="component-body component-id-{{component.id}}-body">
#
#         <!-- Ranked Measure -->
#         <tr ng-repeat-start="measure in component.measures" class="measure">
#             <td ng-if="measure.showDetails != 1 || snapshot_printing" class="name measure-name" title="{{measure.description}}">
#               <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#               <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#             </td>
#             <td ng-if="measure.showDetails == 1 && !snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#                 <a ui-sref="measures.state.tab({ category: categoryId == 1 ? 'outcomes' : 'factors', measure: measure.id, tab: 'map' })">
#                   <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#                   <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#                 </a>
#             </td>
#             <td ng-if="!snapshot_printing" class="info noPrint popover--wide"><span class="fa fa-info-circle" ng-if="measure.hasFootnote"
#                     data-bs-popover="footnotePopover"
#                     data-placement="bottom"
#                     data-trigger="click"
#                     data-container="body"
#                     data-content="{{'FOOTNOTE_'+measure.footnote_id | translate}}"
#                     data-event-type="snapshot"
#                     data-event-key-1="{{measure.name}}"
#                     data-event-key-2="{{current.year}}"
#                     data-html="true"><span>(Click for info)</span>
#                 </span>
#               <span class="fa fa-info-circle" ng-if="measure.id === 1 && cdcData.length"
#                 data-bs-popover="cdcPopover"
#                 data-placement="bottom"
#                 data-trigger="click"
#                 data-event-type="snapshot"
#                 data-event-key-1="{{measure.name}}"
#                 data-event-key-2="{{current.year}}"
#                 data-content-template="partials/cdc-popover.html"><span>(Click for info)</span>
#             </td>
#             <td class="value" ng-class="{'measure-demographics-available' : isThereDemographicData(measure), 'highlight': measure.area_to_highlight != 0, 'highlight-explore': measure.area_to_highlight == 2, 'highlight-strength': measure.area_to_highlight == 1}">
#                 <div ng-if="isThereDemographicData(measure)" ng-click="toggleMeasureDemographics(measure)">
#                     <div ng-if="measure.area_to_highlight == 2" ng-bind-html="measure.displayValue"></div>
#                     <span ng-if="measure.area_to_highlight != 2" ng-bind-html="measure.displayValue"></span>
#                 </div>
#                 <div ng-if="!isThereDemographicData(measure)">
#                     <div ng-if="measure.area_to_highlight == 2" ng-bind-html="measure.displayValue"></div>
#                     <span ng-if="measure.area_to_highlight != 2" ng-bind-html="measure.displayValue"></span>
#                 </div>
#             </td>
#             <!-- Trend -->
#             <td ng-if="isDefaultYear" class="trend-icon-value mobile-drop">
#                 <img ng-if="measure.trend" class="action-trend {{measure.trend}}" data-bs-modal="trendCellModal" data-content="{{measure.trendFile}}" data-template="partials/trend-modal.html" data-html="true" src="{{measure.trendIconPath}}">
#             </td>
#             <!-- Error margin -->
#             <td class="error-margin mobile-drop" ng-bind-html="measure.displayCIRange"></td>
#             <!-- National benchmark -->
#             <td class="target mobile-drop" ng-bind-html="measure.displayTarget"></td>
#
#             <!-- State value -->
#             <td ng-if="current.state_fips != '11'" class="state-value" ng-bind-html="measure.displayState"></td>
#             <!-- Measure row does not show a value for Rank. -->
#             <td ng-if="current.state_fips != '11'" class="rank">&nbsp;</td>
#         </tr>
#         <tr ng-include="'partials/rankings-measure-demographics.html'" ng-repeat-end ng-if="isThereDemographicData(measure)" ng-show="measureDemographicsOpen.indexOf(measure.id)!= -1" class="measure-demographics-drawer">
#         </tr>
#         </tbody>
#
#         <!-- Factor Header - Additional -->
#         <tbody ng-if="component.additional" id="component-id-{{component.id}}-additional" class="component-additional expanded">
#         <tr>
#             <td colspan="{{getHeaderColSpan({base: 7, dc: -2, trend: 1})}}" ng-click="component.showAdditional = !component.showAdditional">
#               <span translate={{"FACTOR_"+component.id+"_ADDITIONAL"}}>Additional {{component.componentName}} (not included in overall ranking)</span>
#               <span ng-hide="snapshot_printing" class="show-hide">{{ component.showAdditional ? '&#8722;' : '+'}}</span>
#             </td>
#         </tr>
#         </tbody>
#         <!-- Factor Body - Additional -->
#         <tbody ng-show="component.showAdditional || snapshot_printing" ng-if="component.additional" id="component-id-{{component.id}}-additional-body" class="component-additional-body expanded">
#         <tr ng-repeat-start="measure in component.additional">
#           <td ng-if="!measure.showDetails || snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#             <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#             <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#           </td>
#           <td ng-if="measure.showDetails && !snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#               <a ui-sref="measures.state.tab({ category: categoryId == 1 ? 'outcomes' : 'factors', measure: measure.id, tab: 'data' })">
#                 <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#                 <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#               </a>
#           </td>
#           <td ng-if="!snapshot_printing" class="info noPrint"><span class="fa fa-info-circle" ng-if="measure.hasFootnote"
#             data-bs-popover="footnotePopover"
#             data-placement="bottom"
#             data-trigger="click"
#             data-container="body"
#             data-content="{{'FOOTNOTE_'+measure.footnote_id | translate}}"
#             data-event-type="snapshot"
#             data-event-key-1="{{measure.name}}"
#             data-event-key-2="{{current.year}}"
#             data-html="true"><span>(Click for info)</span></span>
#           </td>
#           <td ng-click="toggleMeasureDemographics(measure)" class="value" ng-class="{'measure-demographics-available' : isThereDemographicData(measure), highlight: measure.area_to_highlight != 0, 'highlight-explore': measure.area_to_highlight == 2, 'highlight-strength': measure.area_to_highlight == 1}" ng-bind-html="measure.displayValue">
#           </td>
#           <!-- Trend -->
#           <td ng-if="isDefaultYear" class="trend-icon-value mobile-drop">
#             <img ng-if="measure.trend" class="action-trend {{measure.trend}}" data-bs-modal="trendCellModal" data-content="{{measure.trendFile}}" data-template="partials/trend-modal.html" data-html="true" src="{{measure.trendIconPath}}">
#           </td>
#           <!-- Error margin -->
#           <td class="error-margin mobile-drop" ng-bind-html="measure.displayCIRange"></td>
#           <!-- National benchmark -->
#           <td class="target mobile-drop" ng-bind-html="measure.displayTarget"></td>
#
#           <!-- State value -->
#           <td ng-if="current.state_fips != '11'" class="state-value" ng-bind-html="measure.displayState"></td>
#           <!-- Measure row does not show a value for Rank. -->
#           <td ng-if="current.state_fips != '11'" class="rank">&nbsp;</td>
#         </tr>
#         <tr ng-include="'partials/rankings-measure-demographics.html'" ng-repeat-end ng-if="measure.demographics && isThereDemographicData(measure)" ng-show="measureDemographicsOpen.indexOf(measure.id)!= -1" class="measure-demographics-drawer">
#         </tr>
#         </tbody>
#
#         <!-- Close out component repeat for current category -->
#         <tbody ng-repeat-end ng-hide="true"></tbody>
#         <tbody ng-if="category.additional" id="category-id-{{categoryId}-additional" class="category-additional expanded">
#         <tr>
#             <td colspan="{{getHeaderColSpan({base: 7, dc: -2, trend: 1})}}" ng-click="category.showAdditional = !category.showAdditional">
#               <span translate={{"CATEGORY_"+category.id+"_ADDITIONAL"}}>Additional {{category.name}} (not included in overall ranking)</span>
#               <span ng-hide="snapshot_printing" class="show-hide">{{ category.showAdditional ? '&#8722;' : '+'}}</span>
#             </td>
#         </tr>
#         </tbody>
#         <tbody ng-show="category.showAdditional || snapshot_printing" ng-if="category.additional" id="category-id-{{categoryId}-additional-body" class="category-additional-body expanded">
#         <tr ng-repeat-start="measure in category.additional">
#           <td ng-if="measure.showDetails != 1 || snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#             <span ng-bind-html="measure.name" translate={{"MEASURE_"+measure.id}}></span>
#             <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#           </td>
#           <td ng-if="measure.showDetails == 1 && !snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#               <a ui-sref="measures.state.tab({ category: categoryId == 1 ? 'outcomes' : 'factors', measure: measure.id, tab: 'data' })">
#                   <span ng-bind-html="measure.name" translate={{"MEASURE_"+measure.id}}></span>
#                   <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#               </a>
#           </td>
#           <td ng-if="!snapshot_printing" class="info noPrint"><span class="fa fa-info-circle" ng-if="measure.hasFootnote"
#             data-bs-popover="footnotePopover"
#             data-placement="bottom"
#             data-trigger="click"
#             data-container="body"
#             data-content="{{'FOOTNOTE_'+measure.footnote_id | translate}}"
#             data-event-type="snapshot"
#             data-event-key-1="{{measure.name}}"
#             data-event-key-2="{{current.year}}"
#             data-html="true"><span>(Click for info)</span></span>
#           </td>
#           <td ng-click="toggleMeasureDemographics(measure)" class="value" ng-class="{'measure-demographics-available' : isThereDemographicData(measure), highlight: measure.area_to_highlight != 0, 'highlight-explore': measure.area_to_highlight == 2, 'highlight-strength': measure.area_to_highlight == 1}" ng-bind-html="measure.displayValue"></td>
#           <!-- Trend -->
#           <td ng-if="isDefaultYear" class="trend-icon-value mobile-drop">
#               <img ng-if="measure.trend" class="action-trend {{measure.trend}}" data-bs-modal="trendCellModal" data-content="{{measure.trendFilePath}}" data-template="partials/trend-modal.html" data-html="true" src="{{measure.trendIconPath}}">
#           </td>
#           <!-- Error margin -->
#           <td class="error-margin mobile-drop" ng-bind-html="measure.displayCIRange"></td>
#           <!-- National benchmark -->
#           <td class="target mobile-drop" ng-bind-html="measure.displayTarget"></td>
#           <!-- State value -->
#           <td ng-if="current.state_fips != '11'" class="state-value" ng-bind-html="measure.displayState"></td>
#           <!-- Measure row does not show a value for Rank. -->
#           <td ng-if="current.state_fips != '11'" class="rank">&nbsp;</td>
#         </tr>
#         <tr ng-include="'partials/rankings-measure-demographics.html'" ng-repeat-end ng-if="measure.demographics && isThereDemographicData(measure)" ng-show="measureDemographicsOpen.indexOf(measure.id)!= -1" class="measure-demographics-drawer">
#         </tr>
#         </tbody>
#
#         <!-- Close out category repeat -->
#         <tbody ng-repeat-end ng-hide="true"></tbody>
#     </table>
#     <!-- If printing, display the key for Areas to Explore and Areas of Strength highlighting -->
#     <table ng-if="snapshot_printing && (current.year == settings.default_year) && (highlightStrength || highlight)" class="highlight-key">
#       <tr>
#         <td ng-if="highlight" class="highlight-explore">Areas to Explore</td>
#         <td ng-if="highlightStrength" class="highlight-strength">Areas of Strength</td>
#       </tr>
#     </table>
#     <!-- If printing, display the list of footnotes that were used in the snapshot and also the current data year.  -->
#     <table ng-if="snapshot_printing" class="bottom-notes-table">
#       <tbody>
#         <tr ng-repeat="footnote in county.footnotes">
#           <td class="c1">
#             <div>{{footnote.symbol}} {{ 'FOOTNOTE_'+footnote.footnoteId | translate }}</div>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#     <div ng-if="!snapshot_printing" class="bottom-notes noPrint">
#       <div ng-repeat="footnote in county.footnotes" ng-if="footnote.footnoteId == '2'">
#         <div class="other" ng-class="{'target mobile-drop' : footnote.footnoteId == '2'}">{{footnote.symbol}} {{ 'FOOTNOTE_'+footnote.footnoteId | translate }}</div>
#       </div>
#     </div>
# </div>
# </script><script type="text/ng-template" id="partials/rankings-measure-demographics.html"><td colspan="3">
#     <table class="measure-demographics-table">
#         <tbody>
#             <tr>
#               <td class="measure-demographics-drawer-labels first-row">
#                 <span translate={{"MEASURE_"+measure.id+"_RAW_VALUE"}} class="measure-demographic-data-label raw_value"></span>
#               </td>
#               <td class="measure-demographics-drawer-data">
#                 <span class="measure-demographic-data-label raw_value">{{ measure.displayValue }}</span>
#               </td>
#             </tr>
#             <tr ng-repeat="demographic in measure.demographics">
#                 <td class="measure-demographics-drawer-labels">
#                   <span translate={{"MEASURE_"+measure.id+"_"+demographic.translateKey}} class="measure-demographic-data-label"></span>
#                 </td>
#                 <td class="measure-demographics-drawer-data">
#                     <span class="measure-demographic-data-value">{{demographic.value}}</span>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </td>
# <td class="measure-demographics-drawer-toggle" colspan="5">
#     <span ng-hide="snapshot_printing" class="show-hide" ng-click="toggleMeasureDemographics(measure)">x</span>
# </td>
# </script><script type="text/ng-template" id="partials/county-compare.html"><!-- Start Template: county-compare.tpl.php -->
# <div id="main" class="app-section county-compare">
#   <div class="app-header">
#     <h2 ng-show="!dataLoaded">Loading comparison...</h2>
#     <h2 ng-show="dataLoaded">Compare Counties</h2>
# ...
#           <a class="button" ui-sref="downloads()">All Downloads</a>
#         </div>
#         <a class="sub-county-resource-link" href="/using-the-rankings-data/finding-more-data/{{state.path}}" ng-if="state.hasSubCountyData">View more data resources &raquo;</a>
#       </div>
#       <div class="more-data" ng-if="!state.hasSubCountyData">
#         <strong>Find More Data</strong>
#         <div class="details">
#           <p>Check out these other great
#           sources for health and demographics
#           data.</p>
#           <a class="button button--tertiary" href="/using-the-rankings-data/finding-more-data/{{state.path}}">More Data Resources</a>
#         </div>
#       </div>
#       <div class="more-data sub-county" ng-if="state.hasSubCountyData">
#         <strong>{{state.name}} Sub-County Data Reports</strong>
#         <div class="details">
#           {{state.name}} has health data for geographies and demographic groups below the county level.
#           <a class="button" href="{{state.subCountyUrl}}">View The Reports</a>
#         </div>
#       </div>
#     </div>
#     <div id="action-center">
#       <h3>Action Center</h3>
#         <img src="/sites/all/themes/gesso/images/take-action-250-static-2015-notitle.png" />
#       <div class="details">
#         <p>The Action Center provides tools
#         to help groups working together
#         to create healthier places to
#         live, learn, work and play.
#         </p>
#         <a class="button button--tertiary" href="/take-action-improve-health/action-center">View the Action Center</a>
#       </div>
#     </div>
#     <hr class="break" />
#     <div id="state-stories">
#       <h3>Community Stories from {{state.name}}</h3>
#       <div ng-if="overview.story" class="l-slat">
#         <div class="l-slat__media" ng-bind-html="overview.story.image"></div>
#         <div class="l-slat__content" ng-bind-html="overview.story.title"></div>
#       </div>
#       <div ng-if="overview.spotlight" class="l-slat">
#         <div class="l-slat__header"><h6>Community in Action</h6></div>
#         <div class="l-slat__media" ng-bind-html="overview.spotlight.image"></div>
#         <div class="l-slat__content" ng-bind-html="overview.spotlight.title"></div>
#       </div>
#       <p>
#         <a ng-if="overview.story" ng-href="/learn-from-others/stories/browse/{{state.name}}">View more from {{state.name}}...</a>
#       </p>
#       <div ng-if="!overview.story && !overview.spotlight" class="placeholder">
#         <p>
#           <img src="/sites/all/themes/gesso/images/share_your_story.png">
#           Do you have a story to share about
#           health improvement efforts taking place
#           in this state?
#         </p>
#         <a href="/learn-others/stories/submit-story">Share your story</a>
#       </div>
#       <a class="button button--tertiary" href="/learn-from-others/stories">Browse all stories</a>
#     </div>
#     <div id="state-resources">
#       <h3>Community Health Improvement Resources in {{state.name}}</h3>
#       <p>
#         <a href="/using-the-rankings-data/finding-more-data/{{state.path}}#chir">
#           <img src="/sites/all/themes/gesso/images/resources.png" />
#         </a>
#       </p>
#       <a class="button button--tertiary" href="/using-the-rankings-data/finding-more-data/{{state.path}}#chir">Browse resources</a>
#     </div>
#     <div id="state-contacts">
#       <h3>{{state.name}} Contacts</h3>
#       <div ng-bind-html="overview.contacts"></div>
#     </div>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/state-downloads.html"><div id="main" class="app-section">
#   <div class="app-header">
#     <h2 ng-show="!dataLoaded">Loading rankings data...</h2>
#     <h2 ng-show="dataLoaded">{{state.name}} Rankings Data</h2>
#   </div>
#   <div ng-bind-html="downloads"></div>
# </div>
# </script><script type="text/ng-template" id="partials/embeddable-map.html"><div chr-map="chr-map"
#   app-map-type="categories"
#   app-year="{{year}}"
#   app-state="state"
#   app-category="{{mapType}}"
#   app-id="{{mapType|categoryId}}"
#   tooltip="tooltip(mapType, state, county)"></div>
# </script><script type="text/ng-template" id="partials/social-widgets.html"><div id="app-share">
#   <div id="share-js"></div>
#   <div id="share-links">
#     <div id="share-wrapper-{{service}}" class="wrapper" ng-repeat="(service,widget) in shareWidgets" ng-bind-html="widget.content">
#     </div>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/top-performers-tooltip.html"><h3 class="popover-title" translate="COUNTIES_BENCHMARK">Counties Setting a Benchmark</h3>
# <span class="top-performers">
#   <p translate="TOP_PERFORMERS">10th/90th percentile, i.e., only 10% are better</p>
# </span></script><script type="text/ng-template" id="partials/trend-info-tooltip.html"><h3 class="popover-title" translate="TREND_DATA">Trend Data</h3>
# <div class="trend-info-popover-content">
#   <p translate="GRAPH_ICON_INFO">You can view a detailed graph of available trend data by clicking the graph icons. Each icon is color-coded to help you in determining your county's progress:</p>
#   <ul class="trend-key">
#     <li class="trend-decline">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-decline.png" alt="" />        <span translate="COUNTY_WORSE">Your county is getting worse for this measure</span>
#     </li>
#     <li class="trend-steady">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-steady.png" alt="" />        <span translate="COUNTY_SAME">Your county is staying the same for this measure</span>
#     </li>
#     <li class="trend-increase">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-increase.png" alt="" />        <span translate="COUNTY_BETTER">Your county is getting better for this measure</span>
#     </li>
#     <li class="trend-na">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-na.png" alt="" />        <span translate="COUNTY_MORE_INFO">Additional information is needed to interpret the trend for this measure. See below.</span>
#     </li>
#   </ul>
#   <p><a href="/explore-health-rankings/why-ranks-change/understanding-rankings-trends" translate="LEARN_MORE_TRENDS">Learn more about understanding trends and measuring progress</a></p>
# </div>
# </script><script type="text/ng-template" id="partials/peer-compare-tooltip.html"><div class="peer-compare-tooltip-content">
#     <p>County Health Rankings & Roadmaps and CDC's Community Health Status Indicators (CHSI) have teamed up to offer an enhanced peer county comparison feature based on key demographic, social, and economic indicators. Read more about the methodology of peer counties <a href="/peer-counties-methodology">here</a>.</p>
# </div>
# </script><script type="text/ng-template" id="partials/trend-modal.html"><div class="trend-modal modal" tabindex="-1" role="dialog">
#   <div class="modal-dialog">
#     <div class="modal-content">
#       <button class="close-button" type="button" ng-click="$hide()"><span>&times;</span></button>
#       <div class="modal-body" ng-bind="content"></div>
#     </div>
#   </div>
# </div></script><script type="text/ng-template" id="partials/header.html"><ul class="tabs">
#   <li class="tab-overview">
#     <a ng-class="{active: $state.includes('overview')}" ui-sref="overview">Overview</a>
#   </li>
#   <li class="tab-rankings">
#     <a ng-class="{active: $state.includes('rankings')}" ui-sref="rankings.state({category: 'outcomes', component: 'overall'})">Rankings</a>
#   </li>
#   <li class="tab-measures">
#     <a ng-class="{active: $state.includes('measures')}" ui-sref="measures.state({category: 'outcomes', measure: 1})">Measures</a>
#   </li>
#   <li class="tab-downloads" ng-if="!mobile">
#     <a ng-class="{active: $state.includes('downloads')}" ui-sref="downloads">Downloads</a>
#   </li>
#   <li class="tab-compare" ng-if="!mobile">
#     <a ng-class="{active: $state.includes('compare')}" ui-sref="compare.snapshot({lang:'en'})" ui-sref-opts="{reload: true, notify: true}">Compare Counties</a>
#   </li>
# </ul>
# <div ng-if="!mobile && !(narrow && $state.includes('compare'))" county-select>Autocomplete</div>
# <div ng-if="!mobile" class="desktop-links">
#   <a ng-if="$state.is('rankings.county.snapshot')" class="print-link" bs-popover data-content-template="partials/print-popover.html" data-content="placeholder" data-title="Print county snapshots" data-placement="bottom" data-container="body" translate="PRINT">Print</a>
#   <a ng-if="!$state.is('rankings.county.snapshot')" class="print-link" ng-click="print()" translate="PRINT">Print</a>
#   <a class="help-link" href="/explore-health-rankings/use-data" target="_blank" translate="HELP"><img style="vertical-align: middle; padding-bottom: 4px;" src="/sites/all/themes/gesso/images/question.png" />Help</a>
# </div>
# <div class="translation-links" ng-show="$state.is('rankings.county.snapshot')">
#   <button class="button" ng-click="toggleLanguage()" translate="CURRENT_LANGUAGE"></button>
# </div>
# </script><script type="text/ng-template" id="partials/footer.html"><div ng-if="mobile" class="mobile-links clearfix">
#   <a ui-sref="downloads">Downloads</a>
#   <a href="/explore-health-rankings/use-data" target="_blank"><img style="vertical-align: middle; padding-bottom: 4px;"src="/sites/all/themes/gesso/images/question.png" />Help</a>
# </div>
# <div class="end-cap">
#   <img id="question_bubble" alt="?" src="/sites/all/themes/gesso/images/icon_bubble.png" />
#   <a class="button button--large link" href="/contact">Get Help</a>
#   <p>Ready to take action, but not sure what to do next? <strong>Our team offers personalized, free help.</strong></p>
#  </div>
# </script><script type="text/ng-template" id="partials/body.html"><div id="app-body">
#   <div ui-view>
#   </div>
# </div>
# </script><script type="text/ng-template" id="partials/sidebar.html"><div ng-if="section == 'rankings' || section == 'county' || section == 'measure'" id="sidebar" class="app-section">
#   <div ng-show="true" style="display:none;">
#     <div ng-if="!(mobile && section == 'county')" class="app-nav">
#       <div type="button" class="app-button btn current-page {{'category-'+params.category}}" bs-popover="'partials/nav-popover.html'" data-placement="bottom">
#         <div ng-bind="nav.category | categoryName" class="primary category">&nbsp;</div>
#         <div ng-if="section != 'measure'" class="secondary component" ng-bind-html="nav.component | componentName:components"></div>
#         <div ng-if="section == 'measure'" class="secondary measure" ng-bind-html="nav.measure | measureName:measures"></div>
#         <div id="down-arrow">
#           <img src="/sites/all/themes/gesso/images/downarrow.png" />
#         </div>
#       </div>
#     </div>
#     <!-- Measure mobile subnav -->
#     <select ng-if="mobile && section == 'measure'" ng-model="params.tab" ng-change="goto({tab: params.tab})">
#       <option value="map">Overview</option>
#       <option value="data">Data</option>
#       <option value="description">Description</option>
#       <option value="datasource">Data Source</option>
#       <option value="policies">Policies & Programs</option>
#     </select>
#   </div>
# </div>
# </script></div>    </div>
#
#
#
#
#   </div>
#     </div>  </div>
# </div>
#     </main>
#
#
#   <footer class="footer" role="contentinfo">
#     <div class="region-footer-first">
#       <div class="l-constrain">
#         <div class="region-footer-first__inner">
#           <div class="region-footer-first__left">
#               <div id="block-boxes-constant-contact-universal-embed" class="block block-boxes-simple  block-boxes-constant-contact-universal-embed block--boxes block--boxes-constant-contact-universal-embed">      <div id='boxes-box-constant_contact_universal_embed' class='boxes-box'><div class="boxes-box-content"><script> var _ctct_m = "98f1c71d74379502b40111b8916e1c79"; </script>
# <script id="signupScript" src="//static.ctctcdn.com/js/signup-form-widget/current/signup-form-widget.min.js" async defer></script></div></div>  </div><div id="block-boxes-footer-get-help" class="block block-boxes-simple  block-boxes-footer-get-help block--boxes block--boxes-footer-get-help">    <h2 class="block__title">Ready to take action, but not sure where to start?</h2>
#   <div id='boxes-box-footer_get_help' class='boxes-box'><div class="boxes-box-content"><a class="button" href="/contact">Contact Us</a></div></div>  </div>          </div>
#           <div class="region-footer-first__center">
#               <div id="block-boxes-footer-menu" class="block block-boxes-simple  block-boxes-footer-menu block--boxes block--boxes-footer-menu">      <div id='boxes-box-footer_menu' class='boxes-box'><div class="boxes-box-content"><ul><li><a href="/explore-health-rankings">Explore Health Rankings</a></li>
# 	<li><a href="/take-action-to-improve-health">Take Action To Improve Health</a></li>
# 	<li><a href="/learn-from-others">Learn From Others</a></li>
# 	<li><a href="/what-is-health">What is Health?</a></li>
# 	<li><a href="/reports">Reports</a></li>
# 	<li><a href="/about-us">About Us</a></li>
# 	<li><a href="/news-events">News and Events</a></li>
# </ul><ul><li><a href="/research-grants">Research Grants</a></li>
# 	<li><a href="/about-us/job-opportunities">Job Opportunities</a></li>
# 	<li><a href="/explore-health-rankings/faq-page">FAQ</a></li>
# 	<li><a href="/resources">Tools &amp; Resources</a></li>
# 	<li><a href="/credits">Credits</a></li>
# 	<li><a href="/privacy-policy">Privacy Policy</a></li>
# 	<li><a href="/terms-use">Terms of Use</a></li>
# </ul></div></div>  </div>          </div>
#           <div class="region-footer-first__right">
#               <div id="block-boxes-stay-in-touch" class="block block-boxes-simple  block-boxes-stay-in-touch block--boxes block--boxes-stay-in-touch">    <h2 class="element-invisible block__title">Stay In Touch</h2>
#   <div id='boxes-box-stay_in_touch' class='boxes-box'><div class="boxes-box-content"><div class="subscription-information"><a class="button" href="/newsletter-subscription">Sign up for our emails</a></div>
#
# <div class="social-list social-list--inverted"><a class="social-list__link facebook" href="https://www.facebook.com/CountyHealthRankings">Facebook</a><a class="social-list__link twitter" href="https://twitter.com/CHRankings">Twitter</a><a class="social-list__link youtube" href="http://www.youtube.com/user/CountyHealthRankings">YouTube</a><a class="rss social-list__link" href="/rss.xml">RSS</a></div>
# </div></div>  </div>          </div>
#         </div>
#       </div>
#     </div>
#     <div class="region-footer-second">
#       <div class="l-constrain">
#         <div class="region-footer-second__inner">
#           <div class="region-footer-second__left">
#               <div id="block-boxes-footer-credits" class="block block-boxes-simple  block-boxes-footer-credits block--boxes block--boxes-footer-credits">      <div id='boxes-box-footer_credits' class='boxes-box'><div class="boxes-box-content"><a href="http://uwphi.pophealth.wisc.edu" target="_blank"><img alt="University of Wisconsin Population Health Institute" src="/sites/all/themes/gesso/images/logo-uwi.png" /></a>
# <a href="http://www.rwjf.org" target="_blank"><img alt="Robert Wood Johnson Foundation" src="/sites/all/themes/gesso/images/logo-rwjf.png" /></a>
# </div></div>  </div>          </div>
#           <div class="region-footer-second__right">
#               <div id="block-boxes-footer-copyright" class="block block-boxes-simple  block-boxes-footer-copyright block--boxes block--boxes-footer-copyright">      <div id='boxes-box-footer_copyright' class='boxes-box'><div class="boxes-box-content"><p>© 2019 County Health Rankings. All rights reserved.</p>
# </div></div>  </div>          </div>
#         </div>
#       </div>
#     </div>
#   </footer>
#
# </div>
#     <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_lJmO1XUIe28dLgUTcsmeyKj0__QYvb9TdF6NFzOfsPo.js"></script>
#   </body>
#
# </html>

# %%
soup = BeautifulSoup(html, "html.parser")
print(soup)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="ie6 lt-ie9 lt-ie8 lt-ie7 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 7]>         <html class="ie7 lt-ie9 lt-ie8 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 8]>         <html class="ie8 lt-ie9 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if IE 9]>         <html class="ie9 no-js"  lang="en" dir="ltr"> <![endif]-->
# <!--[if gt IE 9]><!--> <html class="no-js" dir="ltr" lang="en" prefix="fb: http://www.facebook.com/2008/fbml ng: https://angularjs.org og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#"> <!--<![endif]-->
# <head>
# <meta content="chrome=1" http-equiv="X-UA-Compatible"/>
# <base href="/app/"/>
# <meta charset="utf-8"/>
# <!--[if lte IE 8]>
#     <script>
#       document.createElement('ng-include');
#       document.createElement('ng-pluralize');
#       document.createElement('ng-view');
#       document.createElement('ng:include');
#       document.createElement('ng:pluralize');
#       document.createElement('ng:view');
#     </script>
#   <![endif]-->
# <!--[if lt IE 8]>
#     <script src="js/json2.js"></script>
#   <![endif]-->
# <meta content="!" name="fragment"/><link href="https://www.countyhealthrankings.org/sites/all/themes/gesso/favicon.ico" rel="shortcut icon" type="image/vnd.microsoft.icon"/>
# <meta content="County Health Rankings &amp; Roadmaps" property="og:site_name"/>
# <meta content="https://www.countyhealthrankings.org/app" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="Rankings" property="og:title"/>
# <meta content="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/og_logo_map.png" property="og:image"/>
# <meta content="The County Health Rankings..." property="og:description"/>
# <meta content="Drupal 7 (http://drupal.org)" name="generator"/>
# <link href="https://www.countyhealthrankings.org/app" rel="canonical"/>
# <link href="https://www.countyhealthrankings.org/app" rel="shortlink"/>
# <title>Rankings | County Health Rankings &amp; Roadmaps</title>
# <meta content="true" name="HandheldFriendly"/>
# <meta content="width" name="MobileOptimized"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://fonts.googleapis.com/css?family=Lato:300,300i,400,400i,700,700i" rel="stylesheet"/>
# <link href="https://www.countyhealthrankings.org/sites/default/files/css/css_xE-rWrJf-fncB6ztZfd2huxqgxu4WO-qwma6Xer30m4.css" media="all" rel="stylesheet">
# <link href="https://www.countyhealthrankings.org/sites/default/files/css/css_YHoYfdDHJhBk9fafWDBDsJSjINK488FlQXisjG0rcSQ.css" media="all" rel="stylesheet"/>
# <link href="https://www.countyhealthrankings.org/sites/default/files/css/css_HncloJEV201TU1_MXmSB7ZIDGZH0xWVtLayhNIYKF0s.css" media="all" rel="stylesheet"/>
# <link href="https://www.countyhealthrankings.org/sites/default/files/css/css_mX0dnWaQH19maUvGx1X4TNoWiae3zKCzVFqtc2v8wqI.css" media="all" rel="stylesheet"/>
# <link href="https://www.countyhealthrankings.org/sites/default/files/css/css_aGX4S5Gw2k44t_x0TwnW7sCB3tKEzqVdtGWw8Ux4H0o.css" media="all" rel="stylesheet"/>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_yKlfN2sDjSoaIQBuf095xIT3NbJaeqGCcgyQyxSIU_c.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/all/libraries/modernizr/modernizr-custom.js?pvzj65"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js"></script>
# <script>
# window.jQuery || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/jquery/1.8/jquery.min.js'>\x3C/script>")
# </script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_Ue_83Kva_lTYRWiAZpAX_KdvIaglsnzPVl955H8zZA0.js"></script>
# <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.10.2/jquery-ui.min.js"></script>
# <script>
# window.jQuery.ui || document.write("<script src='/sites/all/modules/contrib/jquery_update/replace/ui/ui/minified/jquery-ui.min.js'>\x3C/script>")
# </script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_fnFMT3X1_bhCDaBABvWwi8Yq5Useb8r_XorbufldYMA.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/all/libraries/mediaelement/build/mediaelement-and-player.min.js?v=2.1.6"></script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_mk-Xe5KDVSFHKVF5qTZ9R3hH-bbwxn47n3Jk66UEVX8.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_ek1MBTY1vP7U5uRFRy0H4a3w5VtVp9IB9gJs4tkJEsI.js"></script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_85FQuPhJY-7M8ID4O_j2P0Yje8F2rg9QqB5wfoQ6pNg.js"></script>
# <script>
# window.CKEDITOR_BASEPATH = '/sites/all/libraries/ckeditor/'
# </script>
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_KYDbIQSYZ5htJJEkNT3Pt7h5jt7q5MWTORGvQEf1WaM.js"></script>
# <script>
# jQuery.extend(Drupal.settings, {"basePath":"\/","pathPrefix":"","ajaxPageState":{"theme":"gesso","theme_token":"VfYT13i54A9CqIFcEmpLbSgQlJj9QEKyX5lTvRnTTZY","css":{"modules\/system\/system.base.css":1,"modules\/system\/system.menus.css":1,"modules\/system\/system.messages.css":1,"modules\/system\/system.theme.css":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelementplayer.min.css":1,"misc\/ui\/jquery.ui.core.css":1,"misc\/ui\/jquery.ui.theme.css":1,"misc\/ui\/jquery.ui.menu.css":1,"misc\/ui\/jquery.ui.autocomplete.css":1,"sites\/all\/modules\/contrib\/date\/date_api\/date.css":1,"sites\/all\/modules\/contrib\/date\/date_popup\/themes\/datepicker.1.7.css":1,"modules\/field\/theme\/field.css":1,"sites\/all\/modules\/contrib\/fitvids\/fitvids.css":1,"sites\/all\/modules\/contrib\/footnotes\/footnotes.css":1,"sites\/all\/modules\/contrib\/menu_attach_block\/menu_attach_block.css":1,"modules\/node\/node.css":1,"modules\/user\/user.css":1,"sites\/all\/modules\/contrib\/views\/css\/views.css":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.css":1,"sites\/all\/modules\/contrib\/ctools\/css\/ctools.css":1,"sites\/all\/modules\/contrib\/panels\/css\/panels.css":1,"sites\/all\/libraries\/angular-ui-select\/dist\/select.min.css":1,"sites\/all\/libraries\/select2\/select2.css":1,"sites\/all\/libraries\/bootstrap\/dist\/css\/bootstrap.css":1,"sites\/all\/libraries\/angular-motion\/dist\/angular-motion.css":1,"sites\/all\/modules\/custom\/chr_data\/css\/controls.css":1,"sites\/all\/modules\/custom\/chr_data\/css\/tablesorter.css":1,"sites\/all\/libraries\/fontawesome\/css\/font-awesome.css":1,"sites\/all\/themes\/gesso\/css\/styles.css":1},"js":{"sites\/all\/modules\/custom\/chr_data\/dist\/app.js":1,"sites\/all\/modules\/contrib\/addthis\/addthis.js":1,"public:\/\/google_tag\/google_tag.script.js":1,"sites\/all\/libraries\/modernizr\/modernizr-custom.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jquery\/1.8.3\/jquery.min.js":1,"0":1,"misc\/jquery-extend-3.4.0.js":1,"misc\/jquery.once.js":1,"misc\/drupal.js":1,"sites\/all\/libraries\/fitvids\/jquery.fitvids.js":1,"\/\/ajax.googleapis.com\/ajax\/libs\/jqueryui\/1.10.2\/jquery-ui.min.js":1,"1":1,"sites\/all\/modules\/contrib\/beautytips\/js\/jquery.bt.min.js":1,"sites\/all\/modules\/contrib\/beautytips\/js\/beautytips.min.js":1,"sites\/all\/libraries\/mediaelement\/build\/mediaelement-and-player.min.js":1,"https:\/\/polyfill.io\/v3\/polyfill.min.js?features=URL,fetch,Promise":1,"sites\/all\/modules\/custom\/chr_ww_source\/chr_ww_source.js":1,"sites\/all\/modules\/contrib\/fitvids\/fitvids.js":1,"sites\/all\/libraries\/colorbox\/jquery.colorbox-min.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox.js":1,"sites\/all\/modules\/contrib\/colorbox\/styles\/default\/colorbox_style.js":1,"sites\/all\/modules\/contrib\/colorbox\/js\/colorbox_load.js":1,"sites\/all\/modules\/contrib\/mediaelement\/mediaelement.js":1,"sites\/all\/libraries\/json3\/lib\/json3.js":1,"sites\/all\/libraries\/angular\/angular.js":1,"sites\/all\/libraries\/angular-resource\/angular-resource.js":1,"sites\/all\/libraries\/angular-cookies\/angular-cookies.js":1,"sites\/all\/libraries\/angular-cookies-1-5-9\/angular-cookies.js":1,"sites\/all\/libraries\/angular-sanitize\/angular-sanitize.js":1,"sites\/all\/libraries\/angular-animate\/angular-animate.js":1,"sites\/all\/libraries\/angular-class\/angular-class.js":1,"sites\/all\/libraries\/angular-translate\/dist\/angular-translate.js":1,"sites\/all\/libraries\/angular-translate\/dist\/angular-translate-loader-static-files\/angular-translate-loader-static-files.js":1,"sites\/all\/libraries\/angular-ui-select\/dist\/select.min.js":1,"sites\/all\/libraries\/html5shiv\/dist\/html5shiv.js":1,"sites\/all\/libraries\/es5-shim\/es5-shim.min.js":1,"sites\/all\/libraries\/angular-ui-utils\/index.js":1,"sites\/all\/libraries\/angular-ui-scroll\/dist\/ui-scroll.js":1,"sites\/all\/libraries\/angular-ui-scrollpoint\/dist\/scrollpoint.js":1,"sites\/all\/li ...
# </script>
# </link></head>
# <body class="not-front not-logged-in page-app path-app section-app page-panels">
# <div class="skiplinks">
# <a class="skiplinks__link visually-hidden focusable" href="#main">Skip to main content</a>
# </div>
# <noscript aria-hidden="true"><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-M9JNG4Z" style="display:none;visibility:hidden" title="Google Tag Manager" width="0">Google Tag Manager</iframe></noscript> <div class="site-container">
# <div class="print-header">
# <div class="l-constrain">
# <img alt="County Health Rankings &amp; Roadmaps, A Healthier Nation, County by County" src="/sites/all/themes/gesso/images/printlogo_full.png"/>
# </div>
# </div>
# <header class="header" role="banner">
# <div class="region-header">
# <div class="l-constrain">
# <div class="region-header__first">
# <a class="site-name" href="/" rel="home">
# <h1 class="site-name__text">County Health Rankings &amp; Roadmaps</h1>
# </a>
# </div>
# <div class="region-header__second">
# <div class="block block-menu-menu-utility-menu block--menu block--menu-menu-utility-menu" id="block-menu-menu-utility-menu"> <h2 class="element-invisible block__title">Utility Menu</h2>
# <ul class="nav"><li class="nav__item nav__item--first"><a class="nav__link" href="/about-us" title="">About Us</a></li>
# <li class="nav__item nav__item--last"><a class="nav__link" href="/news-events" title="">News &amp; Events</a></li>
# </ul> </div> <a class="header-rwjf-logo" href="http://www.rwjf.org/">A Robert Wood Johnson Foundation program</a>
# </div>
# </div>
# </div>
# </header>
# <div class="region-navigation"> <div class="l-constrain">
# <div class="region-navigation__inner">
# <div class="block block-system-main-menu block--system block--system-main-menu" id="block-system-main-menu"> <h2 class="element-invisible block__title">Main menu</h2>
# <ul class="nav"><li class="nav__item nav__item--first is-expanded has-children has-subnav"><a class="nav__link" href="/explore-health-rankings">Explore Health Rankings</a><ul class="nav nav--subnav"><li class="nav__item nav__item--first is-collapsed has-children"><a class="nav__link" href="/explore-health-rankings/use-data">Use the Data</a></li>
# <li class="nav__item is-collapsed has-children"><a class="nav__link" href="/explore-health-rankings/measures-data-sources">Measures &amp; Data Sources</a></li>
# <li class="nav__item is-collapsed has-children"><a class="nav__link" href="/explore-health-rankings/our-methods">Our Methods</a></li>
# <li class="nav__item is-collapsed has-children"><a class="nav__link" href="/explore-health-rankings/measuring-progress">Measuring Progress</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a class="nav__link" href="/explore-health-rankings/rankings-data-documentation">Rankings Data &amp; Documentation</a></li>
# </ul></li>
# <li class="nav__item is-expanded has-children has-subnav"><a class="nav__link" href="/take-action-to-improve-health">Take Action to Improve Health</a><ul class="nav nav--subnav"><li class="nav__item nav__item--first is-collapsed has-children"><a class="nav__link" href="/take-action-to-improve-health/what-works-for-health">What Works for Health</a></li>
# <li class="nav__item is-collapsed has-children"><a class="nav__link" href="/take-action-to-improve-health/action-center">Action Center</a></li>
# <li class="nav__item is-collapsed has-children"><a class="nav__link" href="/take-action-to-improve-health/partner-center">Partner Center</a></li>
# <li class="nav__item"><a class="nav__link" href="/take-action-improve-health/community-coaching">Community Learning &amp; Guidance</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a class="nav__link" href="/take-action-to-improve-health/learning-guides">Action Learning Guides</a></li>
# </ul></li>
# <li class="nav__item is-expanded has-children has-subnav"><a class="nav__link" href="/learn-from-others">Learn From Others</a><ul class="nav nav--subnav"><li class="nav__item nav__item--first is-collapsed has-children"><a class="nav__link" href="/webinars" title="">Webinars</a></li>
# <li class="nav__item is-collapsed has-children"><a class="nav__link" href="/learn-from-others/rwjf-culture-of-health-prize">RWJF Culture of Health Prize</a></li>
# <li class="nav__item"><a class="nav__link" href="/learn-others/working-with-others">Working With Others</a></li>
# <li class="nav__item"><a class="nav__link" href="/learn-others/research-articles">Research Articles</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a class="nav__link" href="/learn-from-others/stories">Stories</a></li>
# </ul></li>
# <li class="nav__item"><a class="nav__link" href="/what-is-health">What Is Health?</a></li>
# <li class="nav__item nav__item--last is-collapsed has-children"><a class="nav__link" href="/reports">Reports</a></li>
# </ul> </div> <button class="region-navigation__search-button">Search</button>
# </div>
# </div>
# </div>
# <div class="region-search"> <div class="l-constrain">
# <div class="block block-views-exp-search-results-search-pane block--views block--views--exp-search-results-search-pane" id="block-views-exp-search-results-search-pane"> <form accept-charset="UTF-8" action="/search" id="views-exposed-form-search-results-search-pane" method="get"> <div class="views-widget views-widget--filter-search_api_views_fulltext" id="edit-search-api-views-fulltext-wrapper">
# <input class="form-text form-autocomplete live-results-search-textfield" id="edit-search-api-views-fulltext" maxlength="128" name="search_api_views_fulltext" placeholder="Search by county, state, or topic" size="30" type="text" value=""/><input class="live-result-autocomplete" disabled="disabled" id="edit-search-api-views-fulltext-autocomplete" type="hidden" value="https://www.countyhealthrankings.org/search_api_live_results/search_api_views_search_results"/> </div>
# <div class="views-widget views-widget--submit">
# <input class="button button--submit" id="edit-submit-search-results" name="" type="submit" value="Search"/> </div>
# </form> </div> </div>
# </div>
# <div class="region-breadcrumb-region"> <div class="l-constrain">
# <div class="block block-blockify-blockify-breadcrumb block--blockify block--blockify-blockify-breadcrumb" id="block-blockify-blockify-breadcrumb"> <nav class="breadcrumb" role="navigation"><h2 class="breadcrumb__title">You are here</h2><ol class="breadcrumb__list"><li class="breadcrumb__item"><a href="/">Home</a></li></ol></nav> </div><div class="block block-addthis-addthis-block block--addthis block--addthis-addthis-block" id="block-addthis-addthis-block"> <div class="addthis_toolbox addthis_default_style addthis_16x16_style"><a class="addthis_button_print"></a>
# <a class="addthis_button_email"></a>
# <a class="addthis_button_facebook"></a>
# <a class="addthis_button_twitter"></a>
# </div>
# </div> </div>
# </div>
# <main class="main" id="main" role="main" tabindex="-1">
# <div class="l-single-column">
# <div class="l-constrain">
# <div class="l-single-column__main"> <div class="pane pane--app">
# <div class="pane__content">
# <div class="ng-app:app" id="ng-app" ng-app="app"><!--[if IE 8]>
#   <div id="ie8-warning" class="chr-messages warning">
#     <p><strong>Internet Explorer 8 is no longer supported.</strong> You may proceed with using your current browser, but functionality may be limited.</p>
#     <p>For a better experience, try a newer version of <a href="http://windows.microsoft.com/ie" target="_blank">Internet Explorer</a>, <a href="http://www.google.com/chrome/" target="_blank">Chrome</a>, or <a href="http://www.firefox.com/" target="_blank">Firefox</a>.</p>
#   </div>
# <![endif]-->
# <!--[if lt IE 8]>
#   <script type="text/javascript"
#    src="http://ajax.googleapis.com/ajax/libs/chrome-frame/1/CFInstall.min.js"></script>
#   <style>
#    .chromeFrameInstallDefaultStyle {
#      width: 850px; /* default is 800px */
#      border: 5px solid blue;
#    }
#   </style>
#   <div id="chrome-prompt">
#     You are using an old version of Internet Explorer that is incompatible with this website.<br />
#     For faster browsing and a working back button...<br />
#     <button type="button" onclick="installChrome()">Install Google's Chrome Frame plugin</button>
#   </div>
#   <script>
#    // The conditional ensures that this code will only execute in IE,
#    // Therefore we can use the IE-specific attachEvent without worry
#    var installChrome = function() {
#      CFInstall.check({
#        mode: "inline", // the default
#        node: "chrome-prompt",
#        url: "http://www.google.com/chromeframe/eula.html",
#        destination: window.location.href
#      });
#    };
#  </script>
# <![endif]-->
# <div class="section-{{section}} subsection-{{subsection}} category-{{category}}" id="app-main" ng-class="{'is-dc': isDC}" ng-controller="MainController">
# <div social-widgets="social-widgets"></div>
# <div class="app-header breadcrumb">
# <h1 class="state-header"><a class="back-to-state ng-cloak" ng-cloak="" ui-sref="overview">{{state.name}}</a></h1>
# <div class="statePathDateSelect">
# <ui-select class="app-year-select" ng-model="year" on-select="selectYear(year)" skip-focusser="true" theme="select2">
# <ui-select-match placeholder="Select a year">
# <span ng-bind="$select.selected"></span>
# </ui-select-match>
# <ui-select-choices repeat="year in years | validYears:$stateParams.measure:measures | filter: $select.search | orderBy:year:true">
# <span ng-bind-html="year | highlight: $select.search"></span>
# </ui-select-choices>
# <ui-select-no-choice>
# <span ng-cloak="">No Matches Found</span>
# </ui-select-no-choice>
# </ui-select>
# <ui-select class="app-state-select" ng-model="statePath" on-select="selectState(statePath)" resetselectlist="" skip-focusser="true" theme="select2">
# <ui-select-match placeholder="{{'SELECT_STATE' | translate}}">
# <span ng-bind="$select.selected.name"></span>
# </ui-select-match>
# <ui-select-choices repeat="state in states | toArray | orderBy:'name' | filter: {'name':$select.search}">
# <span ng-bind-html="state | highlight: $select.search"></span>
# </ui-select-choices>
# <ui-select-no-choice>
# <span ng-cloak="">No Matches Found</span>
# </ui-select-no-choice>
# </ui-select>
# </div>
# </div>
# <div id="app-wrapper">
# <div class="app-header nav clearfix" ui-view="header"></div>
# <div id="app-body" ui-view="body"></div>
# <div id="app-footer" ui-view="footer"></div>
# </div>
# </div>
# <script id="partials/app--embeddable.html" type="text/ng-template"><!--[if IE 8]>
# <div id="ie8-warning" class="chr-messages warning">
#   <p><strong>Internet Explorer 8 is no longer supported.</strong> You may proceed with using your current browser, but functionality may be limited.</p>
#   <p>For a better experience, try a newer version of <a href="http://windows.microsoft.com/ie" target="_blank">Internet Explorer</a>, <a href="http://www.google.com/chrome/" target="_blank">Chrome</a>, or <a href="http://www.firefox.com/" target="_blank">Firefox</a>.</p>
# </div>
# <![endif]-->
# <!--[if lt IE 8]>
# <script type="text/javascript"
#         src="http://ajax.googleapis.com/ajax/libs/chrome-frame/1/CFInstall.min.js"></script>
# <style>
#   .chromeFrameInstallDefaultStyle {
#     width: 850px; /* default is 800px */
#     border: 5px solid blue;
#   }
# </style>
# <div id="chrome-prompt">
#   You are using an old version of Internet Explorer that is incompatible with this website.<br/>
#   For faster browsing and a working back button...<br/>
# <button onclick="installChrome()" type="button">Install Google's Chrome Frame plugin</button>
# </div>
# <script>
#   // The conditional ensures that this code will only execute in IE,
#   // Therefore we can use the IE-specific attachEvent without worry
#   var installChrome = function() {
#     CFInstall.check({
#       mode: "inline", // the default
#       node: "chrome-prompt",
#       url: "http://www.google.com/chromeframe/eula.html",
#       destination: window.location.href
#     });
#   };
# </script>
# &lt;![endif]--&gt;
# <div class="section-{{section}} subsection-{{subsection}} category-{{category}}" id="app-main" ng-class="{'is-dc': isDC}" ng-controller="MainController">
# <div id="app-wrapper">
# <div id="app-body" ui-view="body"></div>
# </div>
# </div>
# </div></div></div></div></div></div></main></div></body></html><script id="partials/404.html" type="text/ng-template"><h1>page not found</h1>
#
# <h3>{{text}}</h3>
# </script><script id="partials/map.html" type="text/ng-template"><div class="map-wrapper">
#   <div class="map">
#   </div>
#   <div class="legend-wrapper legend-{{legendType}} category-{{category}}" ng-switch="legendType">
#     <div ng-switch-when="gradient" class="legend legend-gradient">
#       <span class="caption legend-best">Best</span>
#       <span class="legend-key">&nbsp;</span>
#       <span class="caption legend-worst">Worst</span>
#       <div class="caption nr">Missing</div>
#       <div ng-if="notApplicableExists" class="not-applicable">
#         <div class="caption">No Data</div>
#         <span class="caption"></span>
#       </div>
#     </div>
#     <div ng-switch-default class="legend legend-quartile map-ranges">
#       <div class="caption">Rank</div>
#       <span ng-repeat="(quartile,range) in ranges" class="quartile {{quartile}}">{{range}}</span>
#       <div class="caption nr">Not Ranked (NR)</div>
#       <div ng-if="notApplicableExists" class="not-applicable">
#           <div class="caption">No Data</div>
#           <span class="caption"></span>
#       </div>
#     </div>
#   </div>
# </div>
# </script><script id="partials/rankings.html" type="text/ng-template"><div id="main" class="app-section has-sidebar">
#     <div id="sidebar" ui-view="sidebar">
#   </div>
#   <div id="main-inner-wrapper" class="app-section" ui-view>
#   </div>
# </div>
# </script><script id="partials/rankings-sidebar.html" type="text/ng-template"><div class="back-to-map-wrapper" ng-if="!mobile && ($state.includes('rankings.county')) && !isDC">
#   <a class="back-to-map noPrint" ui-sref="rankings.state({category: $stateParams.category, component: $stateParams.component})" translate="BACK_TO_MAP">Back to map</a>
# </div>
# <div measures-navigation ng-if="!mobile || !$state.includes('rankings.county')"></div>
# <div county-rankings-table ng-if="(!mobile || !$state.includes('rankings.county')) && !isDC"></div>
# <div ng-if="!mobile" class="translation-links" ng-show="$state.is('rankings.county.snapshot')">
#   <button class="button" ng-click="toggleLanguage()" translate="CURRENT_LANGUAGE"></button>
# </div>
# </script><script id="partials/rankings-state.html" type="text/ng-template"><div ng-if="!mobile" class="tab-context">
#   <h2 class="ranking-title title">{{rankingsTitle}}</h2>
#   <p class="ranking-description description" ng-show="rankingsDescription">{{rankingsDescription}}</p>
# </div>
# <div ng-if="!mobile" chr-map="chr-map" app-map-type="{{mapType}}" app-category="{{$stateParams.category}}" app-year="{{year}}" app-state="state" app-id="{{mapId}}" tooltip="tooltip(state, county)"></div>
# <div ng-if="county_boundary_note" class="county-boundary-note">
#     <p ng-bind-html="county_boundary_note"></p>
# </div>
# </script><script id="partials/rankings-county.html" type="text/ng-template"><div ng-if="!snapshot-printing" id="county-header" class="clearfix tab-context">
#   <div ng-if="dataLoaded" class="app-header">
#     <h2 class="county-name title">
#       {{countyName}}
#     </h2>
#     <div ng-if="$stateParams.year == settings.default_year" class="areas-to-explore" tooltip="{{exploreTooltip}}" tooltip-placement="top">
#       <input id="highlight-explore" ng-model="highlight" type="checkbox" ng-change="toggleExplore(highlight)">
#       <label for="highlight-explore" translate="EXPLORE_AREAS">Show areas to explore</label>
#       <input id="highlight-strength" ng-model="highlightStrength" type="checkbox" ng-change="toggleStrength(highlightStrength)">
#       <label for="highlight-strength" translate="EXPLORE_AREAS_STRENGTH">>Show areas of strength</label>
#     </div>
#   </div>
# </div>
# <div ng-if="dataLoaded" ng-class="{ 'snapshot-printing': snapshot_printing, 'demographics' : true}">
#   <table class="demographics-header-table">
#     <thead>
#       <tr>
#         <th>
#           <h3 ng-click="showDemographics = !showDemographics">{{ "DEMOGRAPHIC_LABEL" | translate }} <span ng-hide="snapshot_printing" class="show-hide">{{ showDemographics ? '&#8722;' : '+'}}</span></h3>
#         </th>
#       </tr>
#     </thead>
#   </table>
#   <div ng-show="(showDemographics || snapshot_printing)" class="demographics-table-wrapper"">
#     <table>
#       <thead>
#         <tr>
#           <th class="title-th-name">&nbsp;</th>
#           <th ng-show="!snapshot_printing">&nbsp;</th>
#           <th translate="COUNTY_LABEL">County</th>
#           <th translate="STATE_LABEL">State</th>
#         </tr>
#       </thead>
#       <tbody>
#         <tr ng-repeat="row in county.demographics | orderBy: ['-measure_type', 'display_index']" ng-if="!row.view || row.view === 0">
#           <td>
#             <a ng-show="!snapshot_printing" ui-sref="measures.state.tab({ category: 'factors', measure: row.id, tab: 'data' })" translate={{"DEMOGRAPHIC_"+row.id+"_NAME"}}>{{ row.name }}</a>
#             <span ng-show="snapshot_printing" translate={{"DEMOGRAPHIC_"+row.id+"_NAME"}}>{{ row.name }}</span>
#             <span class="symbol measure-footnote" ng-if="snapshot_printing && row.hasFootnote == 1">{{ row.footnoteSymbol }}</span>
#           </td>
#           <td ng-show="!snapshot_printing" class="info">
#             <span ng-if="row.hasFootnote == 1" class="fa fa-info-circle"
#             data-bs-popover="footnotePopover"
#             data-placement="bottom"
#             data-trigger="click"
#             data-container="body"
#             data-content="{{'FOOTNOTE_'+row.footnote_id | translate}}"
#             data-event-type="snapshot"
#             data-event-key-1="County Demographics"
#             data-event-key-2="{{$stateParams.year}}"
#             data-html="true"><span>(Click for info)</span>
#             </span>
#             <span ng-if="row.hasFootnote != 1">&nbsp;</span>
#           </td>
#           <td ng-bind-html="row.county_value"></td>
#           <td ng-bind-html="row.state_value"></td>
#         </tr>
#       </tbody>
#     </table>
#   </div>
# </div>
# <div ng-if="dataLoaded" class="content" ui-view>
# </div>
# </script><script id="partials/rankings-county-additional.html" type="text/ng-template"><div class="additional">
#   <div ng-if="county.additional" ng-bind-html="county.additional">
#     <p ng-if="!dataLoaded" class="loading">Loading additional measures data.</p>
#   </div>
#   <div ng-if="county.additional == ''" class="empty">
#     <p>There are no additional measures for this year to display.</p>
#   </div>
# </div>
# </script><script id="partials/rankings-county-snapshot.html" type="text/ng-template"><div class="snapshot state-{{current.state_fips}}">
#     <table class="sticky-enabled snapshot-data">
#         <thead>
#         <tr>
#             <th class="title-th-name">&nbsp;</th>
#             <th ng-if="!snapshot_printing" class="noPrint">&nbsp;</th>
#             <!-- County name -->
#             <th class="place-name"><span translate="COUNTY_LABEL_PREFIX"></span><span ng-bind-html="county.countyNameHeading"></span><br /><span ng-show="!isTranslated()" translate="COUNTY_LABEL"></span></th>
#             <th ng-if="isDefaultYear" class="trend mobile-drop info">
#                 <span translate="TREND" class="colname">Trend</span>
#                 <span ng-if="!snapshot_printing" class="fa fa-info-circle"
#                       data-bs-popover="trendHeaderTooltip"
#                       data-placement="bottom"
#                       data-trigger="click"
#                       data-event-type="snapshot"
#                       data-event-key-1="Trend"
#                       data-event-key-2="{{current.year}}"
#                       data-content-template="partials/trend-info-tooltip.html"><span>(Click for info)</span></span>
#             </th>
#             <th class="error-margin mobile-drop" translate-attr="{title: 'ERROR_TITLE'}" translate="ERROR_MARGIN">Error<br />Margin</th>
#             <th class="target-value mobile-drop info">
#               <span translate="US_PERFORMERS_LABEL">Top U.S.<br />Performers</span>
#               <span ng-if="snapshot_printing" class="symbol">{{county.footnotes['1'].symbol}}</span>
#               <span ng-if="!snapshot_printing" class="fa fa-info-circle noPrint"
#                 data-bs-popover="topPerformersHeaderTooltip"
#                 data-placement="bottom"
#                 data-trigger="click"
#                 data-event-type="snapshot"
#                 data-event-key-1="Top Performers"
#                 data-event-key-2="{{current.year}}"
#                 data-content-template="partials/top-performers-tooltip.html"><span>(Click for info)</span></span></th>
#             <!-- Statename. -->
#             <th ng-if="current.state_fips != '11'" class="value" title="Overall value for the entire state">{{county.stateName}}</th>
#             <th ng-if="current.state_fips != '11'" class="rank info"><span translate="RANK_OF">Rank<br />(of </span><span>{{county.countiesRankedInState}})</span>
#                 <span ng-if="!snapshot_printing" class="fa fa-info-circle"
#                       data-bs-popover="rankHeaderTooltip"
#                       data-placement="bottom"
#                       data-trigger="click"
#                       data-event-type="snapshot"
#                       data-event-key-1="Rank"
#                       data-event-key-2="{{current.year}}"
#                       data-content-template="partials/rank-info-tooltip.html"><span>(Click for info)</span></span>
#             </th>
#         </tr>
#         </thead>
#
#         <!-- Category Header -->
#         <tbody ng-repeat-start="(categoryId, category) in county.categoryArray" id="category-id-{{categoryId}}" class="category">
#         <tr class="category category-id-{{categoryId}}">
#             <td colspan="{{getHeaderColSpan({base: 6, dc: -1, trend: 1})}}" translate={{"CATEGORY_"+category.id}} class="name category-name">{{category.name}}</td>
#             <td ng-if="current.state_fips != '11'" class="rank category-rank">{{category.rank}}</td>
#         </tr>
#         </tbody>
#
#         <!-- Factor Header -->
#         <tbody ng-repeat-start="component in category.components" id="component-id-{{component.id}}" class="component expanded">
#         <tr class="component">
#             <td colspan="{{getHeaderColSpan({base: 6, dc: -1, trend: 1})}}" ng-click="component.hideRanked = !component.hideRanked" translate={{"FACTOR_"+component.id}} class="name component-name">{{component.componentName}}</td>
#             <td ng-if="current.state_fips != '11'" class="rank component-rank">{{component.rank}}</td>
#         </tr>
#         </tbody>
#
#         <!-- Factor Body -->
#         <tbody ng-hide="component.hideRanked" class="component-body component-id-{{component.id}}-body">
#
#         <!-- Ranked Measure -->
#         <tr ng-repeat-start="measure in component.measures" class="measure">
#             <td ng-if="measure.showDetails != 1 || snapshot_printing" class="name measure-name" title="{{measure.description}}">
#               <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#               <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#             </td>
#             <td ng-if="measure.showDetails == 1 && !snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#                 <a ui-sref="measures.state.tab({ category: categoryId == 1 ? 'outcomes' : 'factors', measure: measure.id, tab: 'map' })">
#                   <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#                   <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#                 </a>
#             </td>
#             <td ng-if="!snapshot_printing" class="info noPrint popover--wide"><span class="fa fa-info-circle" ng-if="measure.hasFootnote"
#                     data-bs-popover="footnotePopover"
#                     data-placement="bottom"
#                     data-trigger="click"
#                     data-container="body"
#                     data-content="{{'FOOTNOTE_'+measure.footnote_id | translate}}"
#                     data-event-type="snapshot"
#                     data-event-key-1="{{measure.name}}"
#                     data-event-key-2="{{current.year}}"
#                     data-html="true"><span>(Click for info)</span>
#                 </span>
#               <span class="fa fa-info-circle" ng-if="measure.id === 1 && cdcData.length"
#                 data-bs-popover="cdcPopover"
#                 data-placement="bottom"
#                 data-trigger="click"
#                 data-event-type="snapshot"
#                 data-event-key-1="{{measure.name}}"
#                 data-event-key-2="{{current.year}}"
#                 data-content-template="partials/cdc-popover.html"><span>(Click for info)</span>
#             </td>
#             <td class="value" ng-class="{'measure-demographics-available' : isThereDemographicData(measure), 'highlight': measure.area_to_highlight != 0, 'highlight-explore': measure.area_to_highlight == 2, 'highlight-strength': measure.area_to_highlight == 1}">
#                 <div ng-if="isThereDemographicData(measure)" ng-click="toggleMeasureDemographics(measure)">
#                     <div ng-if="measure.area_to_highlight == 2" ng-bind-html="measure.displayValue"></div>
#                     <span ng-if="measure.area_to_highlight != 2" ng-bind-html="measure.displayValue"></span>
#                 </div>
#                 <div ng-if="!isThereDemographicData(measure)">
#                     <div ng-if="measure.area_to_highlight == 2" ng-bind-html="measure.displayValue"></div>
#                     <span ng-if="measure.area_to_highlight != 2" ng-bind-html="measure.displayValue"></span>
#                 </div>
#             </td>
#             <!-- Trend -->
#             <td ng-if="isDefaultYear" class="trend-icon-value mobile-drop">
#                 <img ng-if="measure.trend" class="action-trend {{measure.trend}}" data-bs-modal="trendCellModal" data-content="{{measure.trendFile}}" data-template="partials/trend-modal.html" data-html="true" src="{{measure.trendIconPath}}">
#             </td>
#             <!-- Error margin -->
#             <td class="error-margin mobile-drop" ng-bind-html="measure.displayCIRange"></td>
#             <!-- National benchmark -->
#             <td class="target mobile-drop" ng-bind-html="measure.displayTarget"></td>
#
#             <!-- State value -->
#             <td ng-if="current.state_fips != '11'" class="state-value" ng-bind-html="measure.displayState"></td>
#             <!-- Measure row does not show a value for Rank. -->
#             <td ng-if="current.state_fips != '11'" class="rank">&nbsp;</td>
#         </tr>
#         <tr ng-include="'partials/rankings-measure-demographics.html'" ng-repeat-end ng-if="isThereDemographicData(measure)" ng-show="measureDemographicsOpen.indexOf(measure.id)!= -1" class="measure-demographics-drawer">
#         </tr>
#         </tbody>
#
#         <!-- Factor Header - Additional -->
#         <tbody ng-if="component.additional" id="component-id-{{component.id}}-additional" class="component-additional expanded">
#         <tr>
#             <td colspan="{{getHeaderColSpan({base: 7, dc: -2, trend: 1})}}" ng-click="component.showAdditional = !component.showAdditional">
#               <span translate={{"FACTOR_"+component.id+"_ADDITIONAL"}}>Additional {{component.componentName}} (not included in overall ranking)</span>
#               <span ng-hide="snapshot_printing" class="show-hide">{{ component.showAdditional ? '&#8722;' : '+'}}</span>
#             </td>
#         </tr>
#         </tbody>
#         <!-- Factor Body - Additional -->
#         <tbody ng-show="component.showAdditional || snapshot_printing" ng-if="component.additional" id="component-id-{{component.id}}-additional-body" class="component-additional-body expanded">
#         <tr ng-repeat-start="measure in component.additional">
#           <td ng-if="!measure.showDetails || snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#             <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#             <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#           </td>
#           <td ng-if="measure.showDetails && !snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#               <a ui-sref="measures.state.tab({ category: categoryId == 1 ? 'outcomes' : 'factors', measure: measure.id, tab: 'data' })">
#                 <span translate={{"MEASURE_"+measure.id}} ng-bind-html="measure.name"></span>
#                 <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#               </a>
#           </td>
#           <td ng-if="!snapshot_printing" class="info noPrint"><span class="fa fa-info-circle" ng-if="measure.hasFootnote"
#             data-bs-popover="footnotePopover"
#             data-placement="bottom"
#             data-trigger="click"
#             data-container="body"
#             data-content="{{'FOOTNOTE_'+measure.footnote_id | translate}}"
#             data-event-type="snapshot"
#             data-event-key-1="{{measure.name}}"
#             data-event-key-2="{{current.year}}"
#             data-html="true"><span>(Click for info)</span></span>
#           </td>
#           <td ng-click="toggleMeasureDemographics(measure)" class="value" ng-class="{'measure-demographics-available' : isThereDemographicData(measure), highlight: measure.area_to_highlight != 0, 'highlight-explore': measure.area_to_highlight == 2, 'highlight-strength': measure.area_to_highlight == 1}" ng-bind-html="measure.displayValue">
#           </td>
#           <!-- Trend -->
#           <td ng-if="isDefaultYear" class="trend-icon-value mobile-drop">
#             <img ng-if="measure.trend" class="action-trend {{measure.trend}}" data-bs-modal="trendCellModal" data-content="{{measure.trendFile}}" data-template="partials/trend-modal.html" data-html="true" src="{{measure.trendIconPath}}">
#           </td>
#           <!-- Error margin -->
#           <td class="error-margin mobile-drop" ng-bind-html="measure.displayCIRange"></td>
#           <!-- National benchmark -->
#           <td class="target mobile-drop" ng-bind-html="measure.displayTarget"></td>
#
#           <!-- State value -->
#           <td ng-if="current.state_fips != '11'" class="state-value" ng-bind-html="measure.displayState"></td>
#           <!-- Measure row does not show a value for Rank. -->
#           <td ng-if="current.state_fips != '11'" class="rank">&nbsp;</td>
#         </tr>
#         <tr ng-include="'partials/rankings-measure-demographics.html'" ng-repeat-end ng-if="measure.demographics && isThereDemographicData(measure)" ng-show="measureDemographicsOpen.indexOf(measure.id)!= -1" class="measure-demographics-drawer">
#         </tr>
#         </tbody>
#
#         <!-- Close out component repeat for current category -->
#         <tbody ng-repeat-end ng-hide="true"></tbody>
#         <tbody ng-if="category.additional" id="category-id-{{categoryId}-additional" class="category-additional expanded">
#         <tr>
#             <td colspan="{{getHeaderColSpan({base: 7, dc: -2, trend: 1})}}" ng-click="category.showAdditional = !category.showAdditional">
#               <span translate={{"CATEGORY_"+category.id+"_ADDITIONAL"}}>Additional {{category.name}} (not included in overall ranking)</span>
#               <span ng-hide="snapshot_printing" class="show-hide">{{ category.showAdditional ? '&#8722;' : '+'}}</span>
#             </td>
#         </tr>
#         </tbody>
#         <tbody ng-show="category.showAdditional || snapshot_printing" ng-if="category.additional" id="category-id-{{categoryId}-additional-body" class="category-additional-body expanded">
#         <tr ng-repeat-start="measure in category.additional">
#           <td ng-if="measure.showDetails != 1 || snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#             <span ng-bind-html="measure.name" translate={{"MEASURE_"+measure.id}}></span>
#             <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#           </td>
#           <td ng-if="measure.showDetails == 1 && !snapshot_printing" class="name measure-name" translate-attr="{{ isDefaultYear ? {title: 'MEASURE_'+measure.id+'_TITLE'} : {} }}">
#               <a ui-sref="measures.state.tab({ category: categoryId == 1 ? 'outcomes' : 'factors', measure: measure.id, tab: 'data' })">
#                   <span ng-bind-html="measure.name" translate={{"MEASURE_"+measure.id}}></span>
#                   <span class="symbol measure-footnote" ng-if="snapshot_printing && measure.hasFootnote == 1">{{ measure.footnoteSymbol }}</span>
#               </a>
#           </td>
#           <td ng-if="!snapshot_printing" class="info noPrint"><span class="fa fa-info-circle" ng-if="measure.hasFootnote"
#             data-bs-popover="footnotePopover"
#             data-placement="bottom"
#             data-trigger="click"
#             data-container="body"
#             data-content="{{'FOOTNOTE_'+measure.footnote_id | translate}}"
#             data-event-type="snapshot"
#             data-event-key-1="{{measure.name}}"
#             data-event-key-2="{{current.year}}"
#             data-html="true"><span>(Click for info)</span></span>
#           </td>
#           <td ng-click="toggleMeasureDemographics(measure)" class="value" ng-class="{'measure-demographics-available' : isThereDemographicData(measure), highlight: measure.area_to_highlight != 0, 'highlight-explore': measure.area_to_highlight == 2, 'highlight-strength': measure.area_to_highlight == 1}" ng-bind-html="measure.displayValue"></td>
#           <!-- Trend -->
#           <td ng-if="isDefaultYear" class="trend-icon-value mobile-drop">
#               <img ng-if="measure.trend" class="action-trend {{measure.trend}}" data-bs-modal="trendCellModal" data-content="{{measure.trendFilePath}}" data-template="partials/trend-modal.html" data-html="true" src="{{measure.trendIconPath}}">
#           </td>
#           <!-- Error margin -->
#           <td class="error-margin mobile-drop" ng-bind-html="measure.displayCIRange"></td>
#           <!-- National benchmark -->
#           <td class="target mobile-drop" ng-bind-html="measure.displayTarget"></td>
#           <!-- State value -->
#           <td ng-if="current.state_fips != '11'" class="state-value" ng-bind-html="measure.displayState"></td>
#           <!-- Measure row does not show a value for Rank. -->
#           <td ng-if="current.state_fips != '11'" class="rank">&nbsp;</td>
#         </tr>
#         <tr ng-include="'partials/rankings-measure-demographics.html'" ng-repeat-end ng-if="measure.demographics && isThereDemographicData(measure)" ng-show="measureDemographicsOpen.indexOf(measure.id)!= -1" class="measure-demographics-drawer">
#         </tr>
#         </tbody>
#
#         <!-- Close out category repeat -->
#         <tbody ng-repeat-end ng-hide="true"></tbody>
#     </table>
#     <!-- If printing, display the key for Areas to Explore and Areas of Strength highlighting -->
#     <table ng-if="snapshot_printing && (current.year == settings.default_year) && (highlightStrength || highlight)" class="highlight-key">
#       <tr>
#         <td ng-if="highlight" class="highlight-explore">Areas to Explore</td>
#         <td ng-if="highlightStrength" class="highlight-strength">Areas of Strength</td>
#       </tr>
#     </table>
#     <!-- If printing, display the list of footnotes that were used in the snapshot and also the current data year.  -->
#     <table ng-if="snapshot_printing" class="bottom-notes-table">
#       <tbody>
#         <tr ng-repeat="footnote in county.footnotes">
#           <td class="c1">
#             <div>{{footnote.symbol}} {{ 'FOOTNOTE_'+footnote.footnoteId | translate }}</div>
#           </td>
#         </tr>
#       </tbody>
#     </table>
#     <div ng-if="!snapshot_printing" class="bottom-notes noPrint">
#       <div ng-repeat="footnote in county.footnotes" ng-if="footnote.footnoteId == '2'">
#         <div class="other" ng-class="{'target mobile-drop' : footnote.footnoteId == '2'}">{{footnote.symbol}} {{ 'FOOTNOTE_'+footnote.footnoteId | translate }}</div>
#       </div>
#     </div>
# </div>
# </script><script id="partials/rankings-measure-demographics.html" type="text/ng-template"><td colspan="3">
#     <table class="measure-demographics-table">
#         <tbody>
#             <tr>
#               <td class="measure-demographics-drawer-labels first-row">
#                 <span translate={{"MEASURE_"+measure.id+"_RAW_VALUE"}} class="measure-demographic-data-label raw_value"></span>
#               </td>
#               <td class="measure-demographics-drawer-data">
#                 <span class="measure-demographic-data-label raw_value">{{ measure.displayValue }}</span>
#               </td>
#             </tr>
#             <tr ng-repeat="demographic in measure.demographics">
#                 <td class="measure-demographics-drawer-labels">
#                   <span translate={{"MEASURE_"+measure.id+"_"+demographic.translateKey}} class="measure-demographic-data-label"></span>
#                 </td>
#                 <td class="measure-demographics-drawer-data">
#                     <span class="measure-demographic-data-value">{{demographic.value}}</span>
#                 </td>
#             </tr>
#         </tbody>
#     </table>
# </td>
# <td class="measure-demographics-drawer-toggle" colspan="5">
#     <span ng-hide="snapshot_printing" class="show-hide" ng-click="toggleMeasureDemographics(measure)">x</span>
# </td>
# </script><script id="partials/county-compare.html" type="text/ng-template"><!-- Start Template: county-compare.tpl.php -->
# <div id="main" class="app-section county-compare">
#   <div class="app-header">
#     <h2 ng-show="!dataLoaded">Loading comparison...</h2>
#     <h2 ng-show="dataLoaded">Compare Counties</h2>
#     <div ng-show="dataLoaded" class='county-selection-wrapper'>
#         <div class='county-compare-primary-selection-wrapper'>
#           <h4>Select a state and county to begin</h4>
#             <div ng-show="!primaryCountySelected">
#                 <ui-select style="..." ng-model="$parent.countySelection.primaryState" theme="select2" skip-focusser="true" on-select="updateCountiesSelect(countySelection.primaryState)">
#                     <ui-select-match placeholder="Enter or select a state">
#                       <span ng-bind="$select.selected.name"></span>
#                     </ui-select-match>
# ...
#     <div id="state-downloads">
#       <h3>{{state.name}} Downloads & Data Resources</h3>
#       <div class="downloads">
#         <div ng-repeat="download in overview.downloads" ng-bind-html="download" class="download"></div>
#         <div class="details">
#           Download the County Health Rankings data for {{state.name}}
#           <a ui-sref="rankings.county({county:county.path})">{{county.name}}</a>
#           <a class="button" ui-sref="downloads()">All Downloads</a>
#         </div>
#         <a class="sub-county-resource-link" href="/using-the-rankings-data/finding-more-data/{{state.path}}" ng-if="state.hasSubCountyData">View more data resources &raquo;</a>
#       </div>
#       <div class="more-data" ng-if="!state.hasSubCountyData">
#         <strong>Find More Data</strong>
#         <div class="details">
#           <p>Check out these other great
#           sources for health and demographics
#           data.</p>
#           <a class="button button--tertiary" href="/using-the-rankings-data/finding-more-data/{{state.path}}">More Data Resources</a>
#         </div>
#       </div>
#       <div class="more-data sub-county" ng-if="state.hasSubCountyData">
#         <strong>{{state.name}} Sub-County Data Reports</strong>
#         <div class="details">
#           {{state.name}} has health data for geographies and demographic groups below the county level.
#           <a class="button" href="{{state.subCountyUrl}}">View The Reports</a>
#         </div>
#       </div>
#     </div>
#     <div id="action-center">
#       <h3>Action Center</h3>
#         <img src="/sites/all/themes/gesso/images/take-action-250-static-2015-notitle.png" />
#       <div class="details">
#         <p>The Action Center provides tools
#         to help groups working together
#         to create healthier places to
#         live, learn, work and play.
#         </p>
#         <a class="button button--tertiary" href="/take-action-improve-health/action-center">View the Action Center</a>
#       </div>
#     </div>
#     <hr class="break" />
#     <div id="state-stories">
#       <h3>Community Stories from {{state.name}}</h3>
#       <div ng-if="overview.story" class="l-slat">
#         <div class="l-slat__media" ng-bind-html="overview.story.image"></div>
#         <div class="l-slat__content" ng-bind-html="overview.story.title"></div>
#       </div>
#       <div ng-if="overview.spotlight" class="l-slat">
#         <div class="l-slat__header"><h6>Community in Action</h6></div>
#         <div class="l-slat__media" ng-bind-html="overview.spotlight.image"></div>
#         <div class="l-slat__content" ng-bind-html="overview.spotlight.title"></div>
#       </div>
#       <p>
#         <a ng-if="overview.story" ng-href="/learn-from-others/stories/browse/{{state.name}}">View more from {{state.name}}...</a>
#       </p>
#       <div ng-if="!overview.story && !overview.spotlight" class="placeholder">
#         <p>
#           <img src="/sites/all/themes/gesso/images/share_your_story.png">
#           Do you have a story to share about
#           health improvement efforts taking place
#           in this state?
#         </p>
#         <a href="/learn-others/stories/submit-story">Share your story</a>
#       </div>
#       <a class="button button--tertiary" href="/learn-from-others/stories">Browse all stories</a>
#     </div>
#     <div id="state-resources">
#       <h3>Community Health Improvement Resources in {{state.name}}</h3>
#       <p>
#         <a href="/using-the-rankings-data/finding-more-data/{{state.path}}#chir">
#           <img src="/sites/all/themes/gesso/images/resources.png" />
#         </a>
#       </p>
#       <a class="button button--tertiary" href="/using-the-rankings-data/finding-more-data/{{state.path}}#chir">Browse resources</a>
#     </div>
#     <div id="state-contacts">
#       <h3>{{state.name}} Contacts</h3>
#       <div ng-bind-html="overview.contacts"></div>
#     </div>
#   </div>
# </div>
# </script><script id="partials/state-downloads.html" type="text/ng-template"><div id="main" class="app-section">
#   <div class="app-header">
#     <h2 ng-show="!dataLoaded">Loading rankings data...</h2>
#     <h2 ng-show="dataLoaded">{{state.name}} Rankings Data</h2>
#   </div>
#   <div ng-bind-html="downloads"></div>
# </div>
# </script><script id="partials/embeddable-map.html" type="text/ng-template"><div chr-map="chr-map"
#   app-map-type="categories"
#   app-year="{{year}}"
#   app-state="state"
#   app-category="{{mapType}}"
#   app-id="{{mapType|categoryId}}"
#   tooltip="tooltip(mapType, state, county)"></div>
# </script><script id="partials/social-widgets.html" type="text/ng-template"><div id="app-share">
#   <div id="share-js"></div>
#   <div id="share-links">
#     <div id="share-wrapper-{{service}}" class="wrapper" ng-repeat="(service,widget) in shareWidgets" ng-bind-html="widget.content">
#     </div>
#   </div>
# </div>
# </script><script id="partials/top-performers-tooltip.html" type="text/ng-template"><h3 class="popover-title" translate="COUNTIES_BENCHMARK">Counties Setting a Benchmark</h3>
# <span class="top-performers">
#   <p translate="TOP_PERFORMERS">10th/90th percentile, i.e., only 10% are better</p>
# </span></script><script id="partials/trend-info-tooltip.html" type="text/ng-template"><h3 class="popover-title" translate="TREND_DATA">Trend Data</h3>
# <div class="trend-info-popover-content">
#   <p translate="GRAPH_ICON_INFO">You can view a detailed graph of available trend data by clicking the graph icons. Each icon is color-coded to help you in determining your county's progress:</p>
#   <ul class="trend-key">
#     <li class="trend-decline">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-decline.png" alt="" />        <span translate="COUNTY_WORSE">Your county is getting worse for this measure</span>
#     </li>
#     <li class="trend-steady">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-steady.png" alt="" />        <span translate="COUNTY_SAME">Your county is staying the same for this measure</span>
#     </li>
#     <li class="trend-increase">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-increase.png" alt="" />        <span translate="COUNTY_BETTER">Your county is getting better for this measure</span>
#     </li>
#     <li class="trend-na">
#       <img typeof="foaf:Image" src="https://www.countyhealthrankings.org/sites/all/modules/custom/chr_data/images/trend-icons/trend-na.png" alt="" />        <span translate="COUNTY_MORE_INFO">Additional information is needed to interpret the trend for this measure. See below.</span>
#     </li>
#   </ul>
#   <p><a href="/explore-health-rankings/why-ranks-change/understanding-rankings-trends" translate="LEARN_MORE_TRENDS">Learn more about understanding trends and measuring progress</a></p>
# </div>
# </script><script id="partials/peer-compare-tooltip.html" type="text/ng-template"><div class="peer-compare-tooltip-content">
#     <p>County Health Rankings & Roadmaps and CDC's Community Health Status Indicators (CHSI) have teamed up to offer an enhanced peer county comparison feature based on key demographic, social, and economic indicators. Read more about the methodology of peer counties <a href="/peer-counties-methodology">here</a>.</p>
# </div>
# </script><script id="partials/trend-modal.html" type="text/ng-template"><div class="trend-modal modal" tabindex="-1" role="dialog">
#   <div class="modal-dialog">
#     <div class="modal-content">
#       <button class="close-button" type="button" ng-click="$hide()"><span>&times;</span></button>
#       <div class="modal-body" ng-bind="content"></div>
#     </div>
#   </div>
# </div></script><script id="partials/header.html" type="text/ng-template"><ul class="tabs">
#   <li class="tab-overview">
#     <a ng-class="{active: $state.includes('overview')}" ui-sref="overview">Overview</a>
#   </li>
#   <li class="tab-rankings">
#     <a ng-class="{active: $state.includes('rankings')}" ui-sref="rankings.state({category: 'outcomes', component: 'overall'})">Rankings</a>
#   </li>
#   <li class="tab-measures">
#     <a ng-class="{active: $state.includes('measures')}" ui-sref="measures.state({category: 'outcomes', measure: 1})">Measures</a>
#   </li>
#   <li class="tab-downloads" ng-if="!mobile">
#     <a ng-class="{active: $state.includes('downloads')}" ui-sref="downloads">Downloads</a>
#   </li>
#   <li class="tab-compare" ng-if="!mobile">
#     <a ng-class="{active: $state.includes('compare')}" ui-sref="compare.snapshot({lang:'en'})" ui-sref-opts="{reload: true, notify: true}">Compare Counties</a>
#   </li>
# </ul>
# <div ng-if="!mobile && !(narrow && $state.includes('compare'))" county-select>Autocomplete</div>
# <div ng-if="!mobile" class="desktop-links">
#   <a ng-if="$state.is('rankings.county.snapshot')" class="print-link" bs-popover data-content-template="partials/print-popover.html" data-content="placeholder" data-title="Print county snapshots" data-placement="bottom" data-container="body" translate="PRINT">Print</a>
#   <a ng-if="!$state.is('rankings.county.snapshot')" class="print-link" ng-click="print()" translate="PRINT">Print</a>
#   <a class="help-link" href="/explore-health-rankings/use-data" target="_blank" translate="HELP"><img style="vertical-align: middle; padding-bottom: 4px;" src="/sites/all/themes/gesso/images/question.png" />Help</a>
# </div>
# <div class="translation-links" ng-show="$state.is('rankings.county.snapshot')">
#   <button class="button" ng-click="toggleLanguage()" translate="CURRENT_LANGUAGE"></button>
# </div>
# </script><script id="partials/footer.html" type="text/ng-template"><div ng-if="mobile" class="mobile-links clearfix">
#   <a ui-sref="downloads">Downloads</a>
#   <a href="/explore-health-rankings/use-data" target="_blank"><img style="vertical-align: middle; padding-bottom: 4px;"src="/sites/all/themes/gesso/images/question.png" />Help</a>
# </div>
# <div class="end-cap">
#   <img id="question_bubble" alt="?" src="/sites/all/themes/gesso/images/icon_bubble.png" />
#   <a class="button button--large link" href="/contact">Get Help</a>
#   <p>Ready to take action, but not sure what to do next? <strong>Our team offers personalized, free help.</strong></p>
#  </div>
# </script><script id="partials/body.html" type="text/ng-template"><div id="app-body">
#   <div ui-view>
#   </div>
# </div>
# </script><script id="partials/sidebar.html" type="text/ng-template"><div ng-if="section == 'rankings' || section == 'county' || section == 'measure'" id="sidebar" class="app-section">
#   <div ng-show="true" style="display:none;">
#     <div ng-if="!(mobile && section == 'county')" class="app-nav">
#       <div type="button" class="app-button btn current-page {{'category-'+params.category}}" bs-popover="'partials/nav-popover.html'" data-placement="bottom">
#         <div ng-bind="nav.category | categoryName" class="primary category">&nbsp;</div>
#         <div ng-if="section != 'measure'" class="secondary component" ng-bind-html="nav.component | componentName:components"></div>
#         <div ng-if="section == 'measure'" class="secondary measure" ng-bind-html="nav.measure | measureName:measures"></div>
#         <div id="down-arrow">
#           <img src="/sites/all/themes/gesso/images/downarrow.png" />
#         </div>
#       </div>
#     </div>
#     <!-- Measure mobile subnav -->
#     <select ng-if="mobile && section == 'measure'" ng-model="params.tab" ng-change="goto({tab: params.tab})">
#       <option value="map">Overview</option>
#       <option value="data">Data</option>
#       <option value="description">Description</option>
#       <option value="datasource">Data Source</option>
#       <option value="policies">Policies & Programs</option>
#     </select>
#   </div>
# </div>
# </script>
#
#
#
#
# <footer class="footer" role="contentinfo">
# <div class="region-footer-first">
# <div class="l-constrain">
# <div class="region-footer-first__inner">
# <div class="region-footer-first__left">
# <div class="block block-boxes-simple block-boxes-constant-contact-universal-embed block--boxes block--boxes-constant-contact-universal-embed" id="block-boxes-constant-contact-universal-embed"> <div class="boxes-box" id="boxes-box-constant_contact_universal_embed"><div class="boxes-box-content"><script> var _ctct_m = "98f1c71d74379502b40111b8916e1c79"; </script>
# <script async="" defer="" id="signupScript" src="//static.ctctcdn.com/js/signup-form-widget/current/signup-form-widget.min.js"></script></div></div> </div><div class="block block-boxes-simple block-boxes-footer-get-help block--boxes block--boxes-footer-get-help" id="block-boxes-footer-get-help"> <h2 class="block__title">Ready to take action, but not sure where to start?</h2>
# <div class="boxes-box" id="boxes-box-footer_get_help"><div class="boxes-box-content"><a class="button" href="/contact">Contact Us</a></div></div> </div> </div>
# <div class="region-footer-first__center">
# <div class="block block-boxes-simple block-boxes-footer-menu block--boxes block--boxes-footer-menu" id="block-boxes-footer-menu"> <div class="boxes-box" id="boxes-box-footer_menu"><div class="boxes-box-content"><ul><li><a href="/explore-health-rankings">Explore Health Rankings</a></li>
# <li><a href="/take-action-to-improve-health">Take Action To Improve Health</a></li>
# <li><a href="/learn-from-others">Learn From Others</a></li>
# <li><a href="/what-is-health">What is Health?</a></li>
# <li><a href="/reports">Reports</a></li>
# <li><a href="/about-us">About Us</a></li>
# <li><a href="/news-events">News and Events</a></li>
# </ul><ul><li><a href="/research-grants">Research Grants</a></li>
# <li><a href="/about-us/job-opportunities">Job Opportunities</a></li>
# <li><a href="/explore-health-rankings/faq-page">FAQ</a></li>
# <li><a href="/resources">Tools &amp; Resources</a></li>
# <li><a href="/credits">Credits</a></li>
# <li><a href="/privacy-policy">Privacy Policy</a></li>
# <li><a href="/terms-use">Terms of Use</a></li>
# </ul></div></div> </div> </div>
# <div class="region-footer-first__right">
# <div class="block block-boxes-simple block-boxes-stay-in-touch block--boxes block--boxes-stay-in-touch" id="block-boxes-stay-in-touch"> <h2 class="element-invisible block__title">Stay In Touch</h2>
# <div class="boxes-box" id="boxes-box-stay_in_touch"><div class="boxes-box-content"><div class="subscription-information"><a class="button" href="/newsletter-subscription">Sign up for our emails</a></div>
# <div class="social-list social-list--inverted"><a class="social-list__link facebook" href="https://www.facebook.com/CountyHealthRankings">Facebook</a><a class="social-list__link twitter" href="https://twitter.com/CHRankings">Twitter</a><a class="social-list__link youtube" href="http://www.youtube.com/user/CountyHealthRankings">YouTube</a><a class="rss social-list__link" href="/rss.xml">RSS</a></div>
# </div></div> </div> </div>
# </div>
# </div>
# </div>
# <div class="region-footer-second">
# <div class="l-constrain">
# <div class="region-footer-second__inner">
# <div class="region-footer-second__left">
# <div class="block block-boxes-simple block-boxes-footer-credits block--boxes block--boxes-footer-credits" id="block-boxes-footer-credits"> <div class="boxes-box" id="boxes-box-footer_credits"><div class="boxes-box-content"><a href="http://uwphi.pophealth.wisc.edu" target="_blank"><img alt="University of Wisconsin Population Health Institute" src="/sites/all/themes/gesso/images/logo-uwi.png"/></a>
# <a href="http://www.rwjf.org" target="_blank"><img alt="Robert Wood Johnson Foundation" src="/sites/all/themes/gesso/images/logo-rwjf.png"/></a>
# </div></div> </div> </div>
# <div class="region-footer-second__right">
# <div class="block block-boxes-simple block-boxes-footer-copyright block--boxes block--boxes-footer-copyright" id="block-boxes-footer-copyright"> <div class="boxes-box" id="boxes-box-footer_copyright"><div class="boxes-box-content"><p>© 2019 County Health Rankings. All rights reserved.</p>
# </div></div> </div> </div>
# </div>
# </div>
# </div>
# </footer>
#
# <script src="https://www.countyhealthrankings.org/sites/default/files/js/js_lJmO1XUIe28dLgUTcsmeyKj0__QYvb9TdF6NFzOfsPo.js"></script>
